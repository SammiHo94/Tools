# %%
import os
from datetime import date
import pandas as pd
import itertools
import empyrical as empy
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")

# %%
def drawdown_from_price(price):
    if isinstance(price, pd.Series):
        return _drawdown_from_price(price)
    elif isinstance(price, pd.DataFrame):
        return price.apply(_drawdown_from_price)
    else:
        raise non_pd_error

def _drawdown_from_price(price):
    shift_max = price.copy()
    _max = price.iloc[0]
    for i, j in price.items():
        #print('i', i)
        #print('j', j)
        _max = max(_max, j)
        shift_max[i] = _max
    return price / shift_max - 1

def return_to_price(ret, ini=100):
    price_0 = ret.dropna().iloc[:1] * 0 + ini
    price_0.index = [0]
    price = (1+ret).cumprod() * ini
    return pd.concat([price_0, price])

def drawdown_from_return(ret, ini=100):
    price = return_to_price(ret, ini)
    return drawdown_from_price(price).iloc[1:]

def avg_drawdown(ret):
    dd = drawdown_from_return(ret)
    return dd.mean()

def empy_metric(ret):
    if isinstance(ret, pd.DataFrame):
        return ret.apply(empy_metric).T
    total_return = lambda x: (1+x).prod()-1
    met_func = [
        total_return, 
        lambda x: empy.annual_return(x), 
        lambda x: empy.sharpe_ratio(x), 
        lambda x: empy.annual_volatility(x), 
        lambda x: empy.max_drawdown(x), 
        avg_drawdown]
    
    met_func_names = ['total_return', 'annual_return', 'sharpe_ratio', 'annual_volatility', 
                      'max_drawdown', 'avg_drawdown',]
    
    se = pd.Series([f(ret) for f in met_func], met_func_names)
    
    se['return/maxdd'] = -se.annual_return/se.max_drawdown
    se['return/avgdd'] = -se.annual_return/se.avg_drawdown
    
    buy01 = ret.apply(lambda x: 0 if x==0 else 1)
    se['buy_ratio'] = buy01.mean()
    se['flip_ratio'] = (buy01-buy01.shift()).abs().mean()

    return se

# %%
client_weight_agg = {'sharpe_ratio':5,'annual_return':5, 'max_drawdown':5}
def calculation_score(df, client_weight=client_weight_agg):
    df['Sharpe Score'] = df['sharpe_ratio'].apply(lambda x: x if x>0 else 0) * 100
    df['Return Score'] = df['annual_return'].apply(lambda x: 1+x/2) * 100
    df['Max-DD Score'] = df['max_drawdown'].apply(lambda x: 1+x) * 100

    df['Total Score'] = 0
    for score, weight in client_weight.items():
        df['Total Score'] += weight * df[score]
    return df

# %%
def display_df(df, export_img=False, **kwargs):
    df_style = df.style.background_gradient(**kwargs)
    display(df_style)
    
    if export_img:
        try:
            dfi.export(df_style,"tmp.png",table_conversion='matplotlib')
            display(Image("tmp.png"))
        except:
            pass

def show_cum_ret(ret):
    fig, ax = plt.subplots(figsize=(24,15))
    cm = plt.get_cmap('gist_rainbow')
    NUM_COLORS = ret.shape[1]
    ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])

    (1+ret).cumprod().plot(ax=ax)

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_yscale("log")
    plt.show()

# %%
ret_list = [
    './result/2022/cashON_signal/result/ret_slding.csv',
    # './result/2022/cashON_signal/result/ret_extending.csv'
]

# %%
ret_cases = pd.DataFrame()
for path in ret_list:
    df = pd.read_csv(path, index_col=0)
    df.index = pd.to_datetime(df.index)
    ret_cases = pd.concat([ret_cases, df], axis=1)
ret_cases
# Out:
#             lookback1Y_sortbyTotal Score  lookback1Y_sortbysharpe_ratio  \
# 2008-01-02                      0.021031                       0.021031
# 2008-01-03                      0.004646                       0.004646
# 2008-01-04                     -0.008659                      -0.008659
# 2008-01-07                     -0.003824                      -0.003824
# 2008-01-08                      0.002096                       0.002096
# ...                                  ...                            ...
# 2022-07-25                     -0.000582                      -0.000582
# 2022-07-26                     -0.002362                      -0.002362
# 2022-07-27                      0.009400                       0.009400
# 2022-07-28                      0.009597                       0.009597
# 2022-07-29                      0.003906                       0.003906
#
#             lookback1Y_sortbyreturn/avgdd  lookback1Y_sortbymax_drawdown  \
# 2008-01-02                       0.021031                       0.021031
# 2008-01-03                       0.004646                       0.004646
# 2008-01-04                      -0.008659                      -0.008659
# 2008-01-07                      -0.003824                      -0.003824
# 2008-01-08                       0.002096                       0.002096
# ...                                   ...                            ...
# 2022-07-25                      -0.000582                      -0.000582
# 2022-07-26                      -0.002362                      -0.002362
# 2022-07-27                       0.009400                       0.009400
# 2022-07-28                       0.009597                       0.009597
# 2022-07-29                       0.003906                       0.003906
#
#             lookback1Y_sortbyavg_drawdown  lookback2Y_sortbyTotal Score  \
# 2008-01-02                       0.021031                      0.021031
# 2008-01-03                       0.004646                      0.004646
# 2008-01-04                      -0.008659                     -0.008659
# 2008-01-07                      -0.003824                     -0.003824
# 2008-01-08                       0.002096                      0.002096
# ...                                   ...                           ...
# 2022-07-25                      -0.000582                     -0.000582
# 2022-07-26                      -0.002362                     -0.002362
# 2022-07-27                       0.009400                      0.009400
# 2022-07-28                       0.009597                      0.009597
# 2022-07-29                       0.003906                      0.003906
#
#             lookback2Y_sortbysharpe_ratio  lookback2Y_sortbyreturn/avgdd  \
# 2008-01-02                       0.021031                       0.021031
# 2008-01-03                       0.004646                       0.004646
# 2008-01-04                      -0.008659                      -0.008659
# 2008-01-07                      -0.003824                      -0.003824
# 2008-01-08                       0.002096                       0.002096
# ...                                   ...                            ...
# 2022-07-25                      -0.000582                      -0.000582
# 2022-07-26                      -0.002362                      -0.002362
# 2022-07-27                       0.009400                       0.009400
# 2022-07-28                       0.009597                       0.009597
# 2022-07-29                       0.003906                       0.003906
#
#             lookback2Y_sortbymax_drawdown  lookback2Y_sortbyavg_drawdown  ...  \
# 2008-01-02                       0.021031                       0.021031  ...
# 2008-01-03                       0.004646                       0.004646  ...
# 2008-01-04                      -0.008659                      -0.008659  ...
# 2008-01-07                      -0.003824                      -0.003824  ...
# 2008-01-08                       0.002096                       0.002096  ...
# ...                                   ...                            ...  ...
# 2022-07-25                      -0.000582                      -0.000582  ...
# 2022-07-26                      -0.002362                      -0.002362  ...
# 2022-07-27                       0.009400                       0.009400  ...
# 2022-07-28                       0.009597                      -0.000101  ...
# 2022-07-29                       0.003906                       0.003801  ...
#
#             lookback4Y_sortbysharpe_ratio  lookback4Y_sortbyreturn/avgdd  \
# 2008-01-02                       0.021031                       0.021031
# 2008-01-03                       0.004646                       0.004646
# 2008-01-04                      -0.008659                      -0.008659
# 2008-01-07                      -0.003824                      -0.003824
# 2008-01-08                       0.002096                       0.002096
# ...                                   ...                            ...
# 2022-07-25                      -0.000582                      -0.000582
# 2022-07-26                      -0.002362                      -0.002362
# 2022-07-27                       0.009400                       0.009400
# 2022-07-28                       0.009597                       0.009597
# 2022-07-29                       0.003906                       0.003906
#
#             lookback4Y_sortbymax_drawdown  lookback4Y_sortbyavg_drawdown  \
# 2008-01-02                       0.021031                       0.021031
# 2008-01-03                       0.004646                       0.004646
# 2008-01-04                      -0.008659                      -0.008659
# 2008-01-07                      -0.003824                      -0.003824
# 2008-01-08                       0.002096                       0.002096
# ...                                   ...                            ...
# 2022-07-25                      -0.000582                      -0.000582
# 2022-07-26                      -0.002362                      -0.002362
# 2022-07-27                       0.009400                       0.009400
# 2022-07-28                      -0.000101                      -0.000101
# 2022-07-29                       0.003801                       0.003801
#
#             lookback5Y_sortbyTotal Score  lookback5Y_sortbysharpe_ratio  \
# 2008-01-02                      0.021031                       0.021031
# 2008-01-03                      0.004646                       0.004646
# 2008-01-04                     -0.008659                      -0.008659
# 2008-01-07                     -0.003824                      -0.003824
# 2008-01-08                      0.002096                       0.002096
# ...                                  ...                            ...
# 2022-07-25                     -0.000582                      -0.000582
# 2022-07-26                     -0.002362                      -0.002362
# 2022-07-27                      0.009400                       0.009400
# 2022-07-28                      0.009597                       0.009597
# 2022-07-29                      0.003906                       0.003906
#
#             lookback5Y_sortbyreturn/avgdd  lookback5Y_sortbymax_drawdown  \
# 2008-01-02                       0.021031                       0.021031
# 2008-01-03                       0.004646                       0.004646
# 2008-01-04                      -0.008659                      -0.008659
# 2008-01-07                      -0.003824                      -0.003824
# 2008-01-08                       0.002096                       0.002096
# ...                                   ...                            ...
# 2022-07-25                      -0.000582                      -0.000582
# 2022-07-26                      -0.002362                      -0.002362
# 2022-07-27                       0.009400                       0.009400
# 2022-07-28                      -0.000101                      -0.000101
# 2022-07-29                       0.003801                       0.003801
#
#             lookback5Y_sortbyavg_drawdown  no_3vote
# 2008-01-02                       0.021031  0.021031
# 2008-01-03                       0.004646  0.004646
# 2008-01-04                      -0.008659 -0.008659
# 2008-01-07                      -0.003824 -0.003824
# 2008-01-08                       0.002096  0.002096
# ...                                   ...       ...
# 2022-07-25                      -0.000582 -0.000582
# 2022-07-26                      -0.002362 -0.002362
# 2022-07-27                       0.009400  0.009400
# 2022-07-28                       0.009597  0.009597
# 2022-07-29                       0.003906  0.003906
#
# [3670 rows x 26 columns]

# %%
no_3vote_ret = ret_cases['no_3vote']

# %%
ret_cases = ret_cases.drop('no_3vote', axis=1)
ret_cases_stage = (ret_cases!=0).astype(int)
ret_cases_stage
# Out:
#             lookback1Y_sortbyTotal Score  lookback1Y_sortbysharpe_ratio  \
# 2008-01-02                             1                              1
# 2008-01-03                             1                              1
# 2008-01-04                             1                              1
# 2008-01-07                             1                              1
# 2008-01-08                             1                              1
# ...                                  ...                            ...
# 2022-07-25                             1                              1
# 2022-07-26                             1                              1
# 2022-07-27                             1                              1
# 2022-07-28                             1                              1
# 2022-07-29                             1                              1
#
#             lookback1Y_sortbyreturn/avgdd  lookback1Y_sortbymax_drawdown  \
# 2008-01-02                              1                              1
# 2008-01-03                              1                              1
# 2008-01-04                              1                              1
# 2008-01-07                              1                              1
# 2008-01-08                              1                              1
# ...                                   ...                            ...
# 2022-07-25                              1                              1
# 2022-07-26                              1                              1
# 2022-07-27                              1                              1
# 2022-07-28                              1                              1
# 2022-07-29                              1                              1
#
#             lookback1Y_sortbyavg_drawdown  lookback2Y_sortbyTotal Score  \
# 2008-01-02                              1                             1
# 2008-01-03                              1                             1
# 2008-01-04                              1                             1
# 2008-01-07                              1                             1
# 2008-01-08                              1                             1
# ...                                   ...                           ...
# 2022-07-25                              1                             1
# 2022-07-26                              1                             1
# 2022-07-27                              1                             1
# 2022-07-28                              1                             1
# 2022-07-29                              1                             1
#
#             lookback2Y_sortbysharpe_ratio  lookback2Y_sortbyreturn/avgdd  \
# 2008-01-02                              1                              1
# 2008-01-03                              1                              1
# 2008-01-04                              1                              1
# 2008-01-07                              1                              1
# 2008-01-08                              1                              1
# ...                                   ...                            ...
# 2022-07-25                              1                              1
# 2022-07-26                              1                              1
# 2022-07-27                              1                              1
# 2022-07-28                              1                              1
# 2022-07-29                              1                              1
#
#             lookback2Y_sortbymax_drawdown  lookback2Y_sortbyavg_drawdown  ...  \
# 2008-01-02                              1                              1  ...
# 2008-01-03                              1                              1  ...
# 2008-01-04                              1                              1  ...
# 2008-01-07                              1                              1  ...
# 2008-01-08                              1                              1  ...
# ...                                   ...                            ...  ...
# 2022-07-25                              1                              1  ...
# 2022-07-26                              1                              1  ...
# 2022-07-27                              1                              1  ...
# 2022-07-28                              1                              1  ...
# 2022-07-29                              1                              1  ...
#
#             lookback4Y_sortbyTotal Score  lookback4Y_sortbysharpe_ratio  \
# 2008-01-02                             1                              1
# 2008-01-03                             1                              1
# 2008-01-04                             1                              1
# 2008-01-07                             1                              1
# 2008-01-08                             1                              1
# ...                                  ...                            ...
# 2022-07-25                             1                              1
# 2022-07-26                             1                              1
# 2022-07-27                             1                              1
# 2022-07-28                             1                              1
# 2022-07-29                             1                              1
#
#             lookback4Y_sortbyreturn/avgdd  lookback4Y_sortbymax_drawdown  \
# 2008-01-02                              1                              1
# 2008-01-03                              1                              1
# 2008-01-04                              1                              1
# 2008-01-07                              1                              1
# 2008-01-08                              1                              1
# ...                                   ...                            ...
# 2022-07-25                              1                              1
# 2022-07-26                              1                              1
# 2022-07-27                              1                              1
# 2022-07-28                              1                              1
# 2022-07-29                              1                              1
#
#             lookback4Y_sortbyavg_drawdown  lookback5Y_sortbyTotal Score  \
# 2008-01-02                              1                             1
# 2008-01-03                              1                             1
# 2008-01-04                              1                             1
# 2008-01-07                              1                             1
# 2008-01-08                              1                             1
# ...                                   ...                           ...
# 2022-07-25                              1                             1
# 2022-07-26                              1                             1
# 2022-07-27                              1                             1
# 2022-07-28                              1                             1
# 2022-07-29                              1                             1
#
#             lookback5Y_sortbysharpe_ratio  lookback5Y_sortbyreturn/avgdd  \
# 2008-01-02                              1                              1
# 2008-01-03                              1                              1
# 2008-01-04                              1                              1
# 2008-01-07                              1                              1
# 2008-01-08                              1                              1
# ...                                   ...                            ...
# 2022-07-25                              1                              1
# 2022-07-26                              1                              1
# 2022-07-27                              1                              1
# 2022-07-28                              1                              1
# 2022-07-29                              1                              1
#
#             lookback5Y_sortbymax_drawdown  lookback5Y_sortbyavg_drawdown
# 2008-01-02                              1                              1
# 2008-01-03                              1                              1
# 2008-01-04                              1                              1
# 2008-01-07                              1                              1
# 2008-01-08                              1                              1
# ...                                   ...                            ...
# 2022-07-25                              1                              1
# 2022-07-26                              1                              1
# 2022-07-27                              1                              1
# 2022-07-28                              1                              1
# 2022-07-29                              1                              1
#
# [3670 rows x 25 columns]

# %%
mly_list = [
    ('./result/2022/202205v0_till202208/3voteContNdays_(LQD,TIP,VTI)202205v0_till202208.csv', 'vote(LQD,TIP,VTI)'),
    ('./result/2022/202205v0_till202208/5voteContNdays_202205v0_till202208.csv', 'vote(GLD,TLT,LQD,TIP,VTI)'),
    ('./result/2022/202205v0_till202208/3voteContNdays_202205v0_till202208.csv', 'vote(GLD,TLT,TIP)'),
]

# %%
replace_str = 'trans_preds_202205v0_till202208'
preds = pd.DataFrame()
for path, name in mly_list:
    df = pd.read_csv(path, index_col=0)
    df.index = pd.to_datetime(df.index)
    df.columns = [col.replace(replace_str, name) for col in df.columns]
    preds = pd.concat([preds, df], axis=1)
preds
# Out:
#               vote(LQD,TIP,VTI)___freqW  vote(LQD,TIP,VTI)___freqM  \
# Trading Date
# 2008-01-02                          1.0                        1.0
# 2008-01-03                          1.0                        1.0
# 2008-01-04                          1.0                        1.0
# 2008-01-07                          1.0                        1.0
# 2008-01-08                          1.0                        1.0
# ...                                 ...                        ...
# 2022-07-29                          0.0                        0.0
# 2022-08-01                          1.0                        1.0
# 2022-08-02                          1.0                        1.0
# 2022-08-03                          1.0                        1.0
# 2022-08-04                          1.0                        1.0
#
#               vote(LQD,TIP,VTI)___cont1_rb_lookback  \
# Trading Date
# 2008-01-02                                      1.0
# 2008-01-03                                      1.0
# 2008-01-04                                      1.0
# 2008-01-07                                      1.0
# 2008-01-08                                      1.0
# ...                                             ...
# 2022-07-29                                      0.0
# 2022-08-01                                      1.0
# 2022-08-02                                      1.0
# 2022-08-03                                      1.0
# 2022-08-04                                      1.0
#
#               vote(LQD,TIP,VTI)___cont1_rb_follow  \
# Trading Date
# 2008-01-02                                    1.0
# 2008-01-03                                    1.0
# 2008-01-04                                    1.0
# 2008-01-07                                    1.0
# 2008-01-08                                    1.0
# ...                                           ...
# 2022-07-29                                    0.0
# 2022-08-01                                    1.0
# 2022-08-02                                    1.0
# 2022-08-03                                    1.0
# 2022-08-04                                    1.0
#
#               vote(LQD,TIP,VTI)___cont1quit_cont2back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  1.0
# 2022-08-03                                                  1.0
# 2022-08-04                                                  1.0
#
#               vote(LQD,TIP,VTI)___cont1quit_cont2back_rb_follow  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  1.0
# 2022-08-02                                                  1.0
# 2022-08-03                                                  1.0
# 2022-08-04                                                  1.0
#
#               vote(LQD,TIP,VTI)___cont1quit_cont3back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  1.0
# 2022-08-04                                                  1.0
#
#               vote(LQD,TIP,VTI)___cont1quit_cont3back_rb_follow  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  1.0
# 2022-08-02                                                  1.0
# 2022-08-03                                                  1.0
# 2022-08-04                                                  1.0
#
#               vote(LQD,TIP,VTI)___cont1quit_cont4back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  1.0
#
#               vote(LQD,TIP,VTI)___cont1quit_cont4back_rb_follow  ...  \
# Trading Date                                                     ...
# 2008-01-02                                                  1.0  ...
# 2008-01-03                                                  1.0  ...
# 2008-01-04                                                  1.0  ...
# 2008-01-07                                                  1.0  ...
# 2008-01-08                                                  1.0  ...
# ...                                                         ...  ...
# 2022-07-29                                                  0.0  ...
# 2022-08-01                                                  1.0  ...
# 2022-08-02                                                  1.0  ...
# 2022-08-03                                                  1.0  ...
# 2022-08-04                                                  1.0  ...
#
#               vote(GLD,TLT,TIP)___cont3quit_cont4back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  0.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont3quit_cont4back_rb_follow  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  0.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4quit_cont1back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4quit_cont1back_rb_follow  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4quit_cont2back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4quit_cont2back_rb_follow  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4quit_cont3back_rb_lookback  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4quit_cont3back_rb_follow  \
# Trading Date
# 2008-01-02                                                  1.0
# 2008-01-03                                                  1.0
# 2008-01-04                                                  1.0
# 2008-01-07                                                  1.0
# 2008-01-08                                                  1.0
# ...                                                         ...
# 2022-07-29                                                  0.0
# 2022-08-01                                                  0.0
# 2022-08-02                                                  0.0
# 2022-08-03                                                  0.0
# 2022-08-04                                                  0.0
#
#               vote(GLD,TLT,TIP)___cont4_rb_lookback  \
# Trading Date
# 2008-01-02                                      1.0
# 2008-01-03                                      1.0
# 2008-01-04                                      1.0
# 2008-01-07                                      1.0
# 2008-01-08                                      1.0
# ...                                             ...
# 2022-07-29                                      0.0
# 2022-08-01                                      0.0
# 2022-08-02                                      0.0
# 2022-08-03                                      0.0
# 2022-08-04                                      0.0
#
#               vote(GLD,TLT,TIP)___cont4_rb_follow
# Trading Date
# 2008-01-02                                    1.0
# 2008-01-03                                    1.0
# 2008-01-04                                    1.0
# 2008-01-07                                    1.0
# 2008-01-08                                    1.0
# ...                                           ...
# 2022-07-29                                    0.0
# 2022-08-01                                    0.0
# 2022-08-02                                    0.0
# 2022-08-03                                    0.0
# 2022-08-04                                    0.0
#
# [3674 rows x 102 columns]

# %%
pairs = list(itertools.product(list(ret_cases_stage.columns), list(preds.columns)))
len(pairs)
# Out:
# 2550

# %%
combine_cases = pd.DataFrame()
exists_case = []
for a, b in pairs:
    # print(a, b)
    if a == b:
        continue

    if (a, b) in exists_case or (b, a) in exists_case:
        continue

    tmp = pd.concat([ret_cases_stage[a], preds[b]], axis=1).astype(bool)
    # display(tmp)

    name = "({})&({})".format(a, b)
    combine_cases[name] = tmp[a] & tmp[b]

    name = "({})|({})".format(a, b)
    combine_cases[name] = tmp[a] | tmp[b]

    exists_case += [(a, b), (b, a)]
    # display(vote_cases)

    # display(exists_case)

    # if len(vote_cases.columns) >= 4:
    #     break
combine_cases = combine_cases.astype(int)

# %%
combine_cases['no_3vote'] = 1
all_kinds_return = combine_cases.apply(lambda x: x*no_3vote_ret).dropna()
all_kinds_return
# Out:
#             (lookback1Y_sortbyTotal Score)&(vote(LQD,TIP,VTI)___freqW)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback1Y_sortbyTotal Score)|(vote(LQD,TIP,VTI)___freqW)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback1Y_sortbyTotal Score)&(vote(LQD,TIP,VTI)___freqM)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback1Y_sortbyTotal Score)|(vote(LQD,TIP,VTI)___freqM)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback1Y_sortbyTotal Score)&(vote(LQD,TIP,VTI)___cont1_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback1Y_sortbyTotal Score)|(vote(LQD,TIP,VTI)___cont1_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback1Y_sortbyTotal Score)&(vote(LQD,TIP,VTI)___cont1_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback1Y_sortbyTotal Score)|(vote(LQD,TIP,VTI)___cont1_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback1Y_sortbyTotal Score)&(vote(LQD,TIP,VTI)___cont1quit_cont2back_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback1Y_sortbyTotal Score)|(vote(LQD,TIP,VTI)___cont1quit_cont2back_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             ...  \
# 2008-01-02  ...
# 2008-01-03  ...
# 2008-01-04  ...
# 2008-01-07  ...
# 2008-01-08  ...
# ...         ...
# 2022-07-25  ...
# 2022-07-26  ...
# 2022-07-27  ...
# 2022-07-28  ...
# 2022-07-29  ...
#
#             (lookback5Y_sortbyavg_drawdown)|(vote(GLD,TLT,TIP)___cont4quit_cont2back_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback5Y_sortbyavg_drawdown)&(vote(GLD,TLT,TIP)___cont4quit_cont3back_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback5Y_sortbyavg_drawdown)|(vote(GLD,TLT,TIP)___cont4quit_cont3back_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback5Y_sortbyavg_drawdown)&(vote(GLD,TLT,TIP)___cont4quit_cont3back_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback5Y_sortbyavg_drawdown)|(vote(GLD,TLT,TIP)___cont4quit_cont3back_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback5Y_sortbyavg_drawdown)&(vote(GLD,TLT,TIP)___cont4_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback5Y_sortbyavg_drawdown)|(vote(GLD,TLT,TIP)___cont4_rb_lookback)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             (lookback5Y_sortbyavg_drawdown)&(vote(GLD,TLT,TIP)___cont4_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000000
# 2022-07-26                                          -0.000000
# 2022-07-27                                           0.000000
# 2022-07-28                                           0.000000
# 2022-07-29                                           0.000000
#
#             (lookback5Y_sortbyavg_drawdown)|(vote(GLD,TLT,TIP)___cont4_rb_follow)  \
# 2008-01-02                                           0.021031
# 2008-01-03                                           0.004646
# 2008-01-04                                          -0.008659
# 2008-01-07                                          -0.003824
# 2008-01-08                                           0.002096
# ...                                                       ...
# 2022-07-25                                          -0.000582
# 2022-07-26                                          -0.002362
# 2022-07-27                                           0.009400
# 2022-07-28                                           0.009597
# 2022-07-29                                           0.003906
#
#             no_3vote
# 2008-01-02  0.021031
# 2008-01-03  0.004646
# 2008-01-04 -0.008659
# 2008-01-07 -0.003824
# 2008-01-08  0.002096
# ...              ...
# 2022-07-25 -0.000582
# 2022-07-26 -0.002362
# 2022-07-27  0.009400
# 2022-07-28  0.009597
# 2022-07-29  0.003906
#
# [3670 rows x 5101 columns]

# %%
met = empy_metric(all_kinds_return)
met = calculation_score(met)
met.sort_values('sharpe_ratio', ascending=False)[:'no_3vote']

# %%
met.sort_values('sharpe_ratio', ascending=False)[:'no_3vote']
# Out:
#                                                     total_return  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      3.825893
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      3.790318
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      3.826692
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      3.777164
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...      3.572098
# ...                                                          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...      2.949797
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...      2.275495
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...      2.916534
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...      2.926330
# no_3vote                                                3.034788
#
#                                                     annual_return  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...       0.114135
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...       0.113569
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...       0.114148
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...       0.113359
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...       0.110010
# ...                                                           ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...       0.098914
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...       0.084879
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...       0.098276
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...       0.098464
# no_3vote                                                 0.100522
#
#                                                     sharpe_ratio  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.911021
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.906577
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.898226
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.892665
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...      0.885945
# ...                                                          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...      0.789918
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...      0.789889
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...      0.789857
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...      0.789712
# no_3vote                                                0.789674
#
#                                                     annual_volatility  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...           0.127604
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...           0.127680
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...           0.129742
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...           0.129759
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...           0.126931
# ...                                                               ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...           0.130168
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...           0.110954
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...           0.129300
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...           0.129590
# no_3vote                                                     0.132437
#
#                                                     max_drawdown  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.206512
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.206512
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.216326
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.219639
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...     -0.206512
# ...                                                          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...     -0.222995
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...     -0.157565
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...     -0.220749
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...     -0.206589
# no_3vote                                               -0.222995
#
#                                                     avg_drawdown  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.045252
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.045571
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.050523
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     -0.051395
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...     -0.046093
# ...                                                          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...     -0.054774
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...     -0.039730
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...     -0.054002
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...     -0.052797
# no_3vote                                               -0.055768
#
#                                                     return/maxdd  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.552680
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.549940
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.527665
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      0.516114
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...      0.532704
# ...                                                          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...      0.443570
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...      0.538692
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...      0.445194
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...      0.476620
# no_3vote                                                0.450779
#
#                                                     return/avgdd  buy_ratio  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      2.522213   0.951771
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      2.492145   0.953951
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      2.259311   0.961035
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...      2.205623   0.961580
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...      2.386663   0.944959
# ...                                                          ...        ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...      1.805866   0.962943
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...      2.136401   0.750409
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...      1.819850   0.972207
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...      1.864953   0.968120
# no_3vote                                                1.802511   1.000000
#
#                                                     flip_ratio  Sharpe Score  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    0.018534     91.102075
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    0.016353     90.657705
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    0.020169     89.822580
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    0.019079     89.266491
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...    0.020169     88.594527
# ...                                                        ...           ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...    0.021259     78.991822
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...    0.035159     78.988940
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...    0.008177     78.985708
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...    0.014718     78.971174
# no_3vote                                              0.000000     78.967389
#
#                                                     Return Score  \
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    105.706742
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    105.678448
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    105.707376
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...    105.667936
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...    105.500480
# ...                                                          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...    104.945702
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...    104.243964
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...    104.913803
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...    104.923224
# no_3vote                                              105.026082
#
#                                                     Max-DD Score  Total Score
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     79.348844     4.093220
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     79.348844     4.068172
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     78.367417     3.980237
# (lookback3Y_sortbymax_drawdown)|(vote(GLD,TLT,L...     78.036111     3.931924
# (lookback5Y_sortbymax_drawdown)|(vote(GLD,TLT,T...     79.348844     3.947216
# ...                                                          ...          ...
# (lookback1Y_sortbyavg_drawdown)|(vote(GLD,TLT,T...     77.700450     3.329184
# (lookback1Y_sortbyreturn/avgdd)&(vote(GLD,TLT,L...     84.243461     3.586016
# (lookback4Y_sortbymax_drawdown)|(vote(LQD,TIP,V...     77.925125     3.336922
# (lookback4Y_sortbysharpe_ratio)|(vote(GLD,TLT,L...     79.341105     3.407936
# no_3vote                                               77.700450     3.336000
#
# [1613 rows x 14 columns]

# %%
all_kinds_return.to_csv('./result/2022/cashON_signal/result/ret_slding&ML.csv')
met.to_csv('./result/2022/cashON_signal/result/met_slding&ML.csv')
