# %%
import os
import pandas as pd
import numpy as np
import math
import empyrical as empy

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap, LinearSegmentedColormap


from sklearn.metrics import accuracy_score, precision_score, explained_variance_score, mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
csv = './data/XAU_USD.csv'
start = '1985'
end = '2021'

# %%
sma = lambda x, y: x.rolling(int(y)).mean()

ewma = lambda x, y: x.ewm(span=y).mean()

def s(x,x0,x1,y0=0,y1=1,d=np.nan):
    if x>=x1:
        return y1
    if x<x0:
        return y0
    return d

# %%
price = pd.read_csv(csv, index_col=0)['adj_close']
price.index = pd.to_datetime(price.index)

true_ret = price.pct_change()
true_yret = empy.aggregate_returns(true_ret, convert_to='yearly')
true_mret = empy.aggregate_returns(true_ret, convert_to='monthly')

# %%
true_up = (true_ret>=0).astype(int)

# %%
price[start:end].plot()
# plt.show()
# true_mret.plot()
# plt.show()
# true_yret.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
period_index = price.index.to_period('W')
weeklyprice = price.groupby(period_index).nth(-1)
weeklyprice.index = [idx.end_time.date() for idx in weeklyprice.index]
weeklyprice.index = pd.to_datetime(weeklyprice.index)
weeklyprice[start:end].plot()
# Out:
# <AxesSubplot:>

# %%
ll = [34 + n*8 for n in range(0, 8)]
ll.sort()
sma_all = {'sma{}'.format(span): sma(weeklyprice.shift(), span) for span in ll}
sma_all = pd.DataFrame(sma_all).dropna()
sma_all

# %%
polt_sma_df = pd.concat([weeklyprice, sma_all], axis=1)
polt_sma_df[start:end].plot(figsize=(12,6))
polt_sma_df['1988':'2000'].plot(figsize=(12,6))
polt_sma_df['2001':'2005'].plot(figsize=(12,6))
polt_sma_df['2006':'2008'].plot(figsize=(12,6))
polt_sma_df['2009':'2011'].plot(figsize=(12,6))
polt_sma_df['2012':'2015'].plot(figsize=(12,6))
polt_sma_df['2016':'2021'].plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
import itertools
t = list(sma_all.columns)
c = list(itertools.combinations(t, 2))
pairs = list(set(c))
pairs.sort()
# pairs

# %%
def plot_with_flip(df, flip_df, sma_baseline, cont_min=4*6):
    maxvalue = df.max().max()
    minvalue = df.min().min()

    fig, ax = plt.subplots(figsize=(12,6))
    df.plot(ax=ax)
    previous_loc = None
    count_cont = 0
    for idx in flip_df.index:
        # print("==================================================")
        # print(idx, flip_df[idx], previous_loc)
        if flip_df[idx] or idx == flip_df.index[-1]:
            # plt.vlines(idx, minvalue, maxvalue)
        
            if previous_loc is None:
                previous_loc = (idx, sma_baseline[idx])
            else:
                current_loc = sma_baseline[idx]

                if count_cont >= cont_min:
                    if previous_loc[1] < current_loc:
                        facecolor ='green'
                    else:
                        facecolor ='red'
                    # print("        previous_loc: ", previous_loc)
                    # print("        current_loc: ", idx, current_loc)
                    # print("        facecolor: ", facecolor)
                    ax.axvspan(previous_loc[0], idx, alpha=0.5, color=facecolor)
                count_cont = 0
                previous_loc = (idx, current_loc)
        else:
            count_cont += 1
            if previous_loc is None:
                previous_loc = (idx, sma_baseline[idx])


    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
flip_df = pd.DataFrame()
for a, b in pairs:
    x = sma_all[a]
    y = sma_all[b]
    diff = x - y
    diff_signal = (diff>0).astype(int)
    flip_df["{}_{}".format(a, b)] = (diff_signal != diff_signal.shift()).dropna()
flip_df

# %%
cont_min = 48

polt_sma_df = pd.concat([weeklyprice, sma_all], axis=1)
cross_any = flip_df.any(axis=1)
# cc = pd.concat([cross_any, cross_any != cross_any.shift()], axis=1)
# cc_flip = cc.all(axis=1)

plot_with_flip(polt_sma_df[start:end], cross_any[start:end], sma_all['sma34'], cont_min)
plot_with_flip(polt_sma_df['1988':'2000'], cross_any['1988':'2000'], sma_all['sma34'], cont_min)
plot_with_flip(polt_sma_df['2001':'2005'], cross_any['2001':'2005'], sma_all['sma34'], cont_min)
plot_with_flip(polt_sma_df['2006':'2008'], cross_any['2006':'2008'], sma_all['sma34'], cont_min)
plot_with_flip(polt_sma_df['2009':'2011'], cross_any['2009':'2011'], sma_all['sma34'], cont_min)
plot_with_flip(polt_sma_df['2012':'2015'], cross_any['2012':'2015'], sma_all['sma34'], cont_min)
plot_with_flip(polt_sma_df['2016':'2021'], cross_any['2016':'2021'], sma_all['sma34'], cont_min)


for i in range(int(start), int(end)):
    plot_with_flip(polt_sma_df[str(i)], cross_any[str(i)], sma_all['sma34'], cont_min)

# %%
weekly_ret = weeklyprice.pct_change()
weekly_up = (weekly_ret >= 0).astype(int)

# %%
lookback = 1
rollback_cross_D1_5 = cross_any.rolling(lookback).apply(lambda x: not x.any())
rollback_cross_D1_5.name = 'phase15_lookback{}W'.format(lookback)
# rollback_cross_D1_5

# %%
sma_trend = sma_all.pct_change(lookback)
sma_trend = (sma_trend>=0).all(axis=1)
#.apply(lambda x: not x.any())
# sma_trend['2008-08':'2008-12']

# %%
# rollback_cross_D1_5
filter_D1_5 = pd.Series(np.nan, index=rollback_cross_D1_5.index)
filter_D1_5.name = rollback_cross_D1_5.name
# cross_period = rollback_cross_D1_5.index[rollback_cross_D1_5!=1]
# filter_D1_5[cross_period] = np.nan

parallel_period = rollback_cross_D1_5.index[rollback_cross_D1_5==1]
parallel_sma_trend = sma_trend[parallel_period]
parallel_up_period = parallel_sma_trend.index[parallel_sma_trend==1]
parallel_down_period = parallel_sma_trend.index[parallel_sma_trend==0]

filter_D1_5[parallel_up_period] = 5
filter_D1_5[parallel_down_period] = 1

# filter_D1_5['2008-08':'2008-12']
# pd.Series(index=parallel_period)['2008-08':'2008-12']

# %%
def drawdown_from_price(price):
    if isinstance(price, pd.Series):
        return _drawdown_from_price(price)
    elif isinstance(price, pd.DataFrame):
        return price.apply(_drawdown_from_price)
    else:
        raise non_pd_error

def _drawdown_from_price(price):
    shift_max = price.copy()
    _max = price.iloc[0]
    for i, j in price.items():
        #print('i', i)
        #print('j', j)
        _max = max(_max, j)
        shift_max[i] = _max
    return price / shift_max - 1

def return_to_price(ret, ini=100):
    price_0 = ret.iloc[:1] * 0 + ini
    price_0.index = [0]
    price = (1+ret).cumprod() * ini
    return pd.concat([price_0, price])

def drawdown_from_return(ret, ini=100):
    price = return_to_price(ret, ini)
    return drawdown_from_price(price).iloc[1:]

def avg_drawdown(ret):
    dd = drawdown_from_return(ret)
    return dd.mean()

# %%
def other_metric(ret):
    if isinstance(ret, pd.DataFrame):
        return ret.apply(other_metric).T
    
    pred_up = (ret!=0)*1
    
    highlight_ratio = pred_up.mean()
    flip_ratio = (pred_up - pred_up.shift()).abs().mean()
    
    idx_tmp = pred_up.index & true_up.index
    true_up_tmp = true_up.reindex(idx_tmp) * 1
    pred_up = pred_up.reindex(idx_tmp) * 1
    accu = accuracy_score(true_up_tmp, pred_up)
    prec = precision_score(true_up_tmp, pred_up)
    
    true_up_pct = true_ret.reindex(idx_tmp)
    true_up_pct_scaled = true_up_pct/true_up_pct.std() + 0.5
    
    mse = mean_squared_error(true_up_pct_scaled, pred_up)
    
    se = pd.Series(dtype='float64')
    
    se['highlight_ratio'] = highlight_ratio
    se['flip_ratio'] = flip_ratio
    se['accu'] = accu
    se['prec'] = prec
    se['mse'] = mse
    
    return se


def empy_metric(ret):
    if isinstance(ret, pd.DataFrame):
        return ret.apply(empy_metric).T
    total_return = lambda x: (1+x).prod()-1
    met_func = [total_return, empy.annual_return, empy.sharpe_ratio, empy.annual_volatility, 
                empy.max_drawdown, avg_drawdown]
    
    met_func_names = ['total_return', 'annual_return', 'sharpe_ratio', 'annual_volatility', 
                      'max_drawdown', 'avg_drawdown',]
    
    se = pd.Series([f(ret) for f in met_func], met_func_names)
    
    se['return/maxdd'] = -se.annual_return/se.max_drawdown
    se['return/avgdd'] = -se.annual_return/se.avg_drawdown
    
    return se

# %%
def print_all_result(ret_df, proba_df=None, topn=10, strategy_list_sel=None, base_case=None):
    
    display('{} to {}'.format(ret_df.index[0], ret_df.index[-1]))
    
    column_selected = ['annual_return', 'sharpe_ratio', 'max_drawdown', 'avg_drawdown', 'return/avgdd',]
    empy_metric_tmp = empy_metric(ret_df).sort_values('sharpe_ratio')
    if strategy_list_sel is None:

        strategy_list_sel = list(empy_metric_tmp.index)

        strategy_list_sel = strategy_list_sel[-topn:]

    if 'buy_and_hold' in strategy_list_sel:
        strategy_list_sel = [x for x in strategy_list_sel if x !='buy_and_hold']
    
    base_list = ['buy_and_hold']
    if base_case is not None:
        for bc in base_case:
            if bc == 'buy_and_hold':
                continue
            else:
                if bc not in strategy_list_sel:
                    base_list.append(bc)
    strategy_list_sel = base_list+strategy_list_sel
    
    other_metric_tmp = other_metric(ret_df)
    
    display(other_metric_tmp.loc[strategy_list_sel[1:]].iloc[:,:5])
    display(empy_metric_tmp.loc[strategy_list_sel][column_selected])
    
    fig, ax = plt.subplots(figsize=(20,15))
    
    cm = plt.get_cmap('gist_rainbow')
    NUM_COLORS = ret_df[strategy_list_sel].shape[1]
    ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


    (1+ret_df[strategy_list_sel]).cumprod().plot(ax=ax)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_yscale("log")
    plt.show()
    
#     cvals  = [0, 0.5, 1]
#     colors = ["red", 'white', "lawngreen"]
#     cmap = LinearSegmentedColormap.from_list("", colors)
#     norm=plt.Normalize(min(cvals),max(cvals))
#     tuples = list(zip(map(norm,cvals), colors))
#     cmap = LinearSegmentedColormap.from_list("", tuples)
#     sm = plt.cm.ScalarMappable(cmap=cmap)#, norm=norm
#     sm.set_array([])

    
    if proba_df is None:
        return strategy_list_sel

    alpha = 1
    dot_size = 20
    
    base_cumret = (1+ret_df['buy_and_hold']).cumprod().apply(math.log)
    base_cumret.name = 'buy_and_hold'
    
    for case in strategy_list_sel:
        if case not in proba_df.columns:
            continue
        print("====================================", case)
#         try:
        if True:
            df_temp = pd.concat([ret_df[case], proba_df[case]],1,keys=['return','pred prob']).dropna()

    #         df_temp['log return'] = (1+df_temp['return']).apply(math.log)
    #         df_temp['cumulative return'] = (1+df_temp['return']).cumprod()-1
            df_temp['log cumulative return'] = (1+df_temp['return']).cumprod().apply(math.log)

            z_ret = ret_df[case]/ret_df[case].std()
            z_prod = (proba_df[case]-0.5)/proba_df[case].std()
            df_temp['score'] = 3-abs(z_ret-z_prod)

            df_temp = df_temp.reset_index()
            df_temp['date'] = pd.to_datetime(df_temp['date'])
            
#             display(df_temp)
            
            plot_hue = 'pred prob'
        
            cvals  = [0,0.5,1]
            colors = ["red","white","lawngreen"]
            norm = plt.Normalize(min(cvals),max(cvals))
            tuples = list(zip(map(norm,cvals), colors))
            cmap_prob = LinearSegmentedColormap.from_list("", tuples)
            sm_prob = plt.cm.ScalarMappable(cmap=cmap_prob, norm=norm)
            sm_prob.set_array([])
            
            fig, ax = plt.subplots(figsize=(20,15))
            ax = sns.scatterplot(data=df_temp, x='date', y='log cumulative return', hue=plot_hue,
                                 #hue='score', alpha=0.5, palette=cmap, s=20)
                                 alpha=0.5, palette=cmap_prob, s=dot_size
#                                  cmap=cmap_prob
                                )
            base_cumret.plot(ax=ax)

            ax.set_xlim([df_temp['date'].iloc[0], df_temp['date'].iloc[-1]])
            ax.get_legend()#.remove()
#             ax.set_yscale("log")
            ax.figure.colorbar(sm_prob)
            ax.set_title("{} {}".format(case, plot_hue))
            plt.show()
            
            fig, ax = plt.subplots(figsize=(12,10))
            proba_df.loc[ret_df.index, case].plot(kind='bar', ax=ax, legend=False)
#             ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
            ax.set_title(case + ' proba')
            plt.show()
#         except Exception as e:
#             print(e)
#             continue
    
    
    return strategy_list_sel

# %%
# true_ret_3stage = pd.cut(weekly_up, bins=[0, 0.3, 0.6, 1], right=True, labels=False).fillna(0)(weekly_up >= 0).astype(int)

bins=[0, 0.4, 0.6, 1]

true_yret_roll_vote_pred = pd.DataFrame(index=weekly_up.index)
true_yret_roll_vote_proba = pd.DataFrame(index=weekly_up.index)
lookbacks = [3, 4, 5, 10, 12, 15, 24, 48]
for lookback in lookbacks:
    true_yret_rollN = weekly_up.shift().rolling(lookback).mean()
    true_yret_rollN.name = 'phase234_lookback{}W_vote'.format(lookback)
    true_yret_roll_vote_proba = pd.concat([true_yret_roll_vote_proba, true_yret_rollN], axis=1)

    pp = pd.cut(true_yret_rollN, bins=bins, right=True, labels=False).fillna(0)
    pp.name = 'phase234_lookback{}W_vote'.format(lookback)
    true_yret_roll_vote_pred = pd.concat([true_yret_roll_vote_pred, pp], axis=1)

true_yret_roll_vote_proba = true_yret_roll_vote_proba.shift().dropna()
true_yret_roll_vote_pred = true_yret_roll_vote_pred.shift().dropna()
true_yret_roll_vote_pred = true_yret_roll_vote_pred + 2

# true_yret_roll_vote_pred.index = pd.to_datetime(['{}-01-01'.format(i) for i in true_yret_roll_vote_pred.index])
# true_yret_roll_vote_proba.index = pd.to_datetime(['{}-01-01'.format(i) for i in true_yret_roll_vote_proba.index])
# true_yret_roll_vote_proba

# %%
price[start:end].plot()
plt.show()

# bounds = pd.DataFrame([[0.5, 0.55]] * len(tt.index), index=tt.index, columns=['lower', 'upper'])
# true_yret_roll_vote_proba.plot().legend(loc='center left', bbox_to_anchor=(1, 0.5))
# plt.hlines(y = 0.5, xmin = true_yret_roll_vote_proba.index[0], xmax = true_yret_roll_vote_proba.index[-1], label ="lower", color='y')
# plt.hlines(y = 0.55, xmin = true_yret_roll_vote_proba.index[0], xmax = true_yret_roll_vote_proba.index[-1], label ="upper", color='g')
# plt.show()

for col in true_yret_roll_vote_proba.columns:
    tt = true_yret_roll_vote_proba[col]
    tt.plot(title=col).legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.hlines(y = bins[1], xmin = true_yret_roll_vote_proba.index[0], xmax = true_yret_roll_vote_proba.index[-1], label ="lower", color='y')
    plt.hlines(y = bins[2], xmin = true_yret_roll_vote_proba.index[0], xmax = true_yret_roll_vote_proba.index[-1], label ="upper", color='g')
    plt.show()

# %%
rollback_cross = pd.DataFrame()
for col in true_yret_roll_vote_pred.columns:
    tmp = pd.concat([true_yret_roll_vote_pred[col], filter_D1_5], axis=1)
    tmp = tmp.fillna(method='ffill', axis=1)
    rollback_cross["{}_{}".format(filter_D1_5.name, col)] = tmp.iloc[:, -1]
# rollback_cross

# %%
def plot_with_flip_5stages(df, rollback_cross):
    maxvalue = df.max().max()
    minvalue = df.min().min()

    facecolor_map = {
        1: 'red',
        2: 'yellow',
        3: 'c',
        4: 'g',
        5: 'lime'
    }

    
    count_cont = 0
    for case in rollback_cross.columns:
        # print("==================================================")
        # print(idx, flip_df[idx], previous_loc)
        stage_ser = rollback_cross[case]

        fig, ax = plt.subplots(figsize=(12,6))
        df.plot(ax=ax)

        previous_stage = None
        for idx in stage_ser.index:
            if previous_stage is None:
                previous_stage = stage_ser[idx]
                baseline_loc = idx
                continue

            current_stage = stage_ser[idx]
            if idx == stage_ser.index[-1]:
                facecolor = facecolor_map[current_stage]
                ax.axvspan(baseline_loc, idx, alpha=0.5, color=facecolor)
                continue

            if current_stage == previous_stage:
                continue
            else:
                facecolor = facecolor_map[previous_stage]
                ax.axvspan(baseline_loc, idx, alpha=0.5, color=facecolor)
                previous_stage = current_stage
                baseline_loc = idx
        ax.set_title(case)
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.show()

# %%
plot_with_flip_5stages(polt_sma_df[start:end], rollback_cross[start:end])

# %%
"""plot_with_flip_5stages(polt_sma_df[start:end], rollback_cross[start:end])
plot_with_flip_5stages(polt_sma_df['1988':'2000'], rollback_cross['1988':'2000'])
plot_with_flip_5stages(polt_sma_df['2001':'2005'], rollback_cross['2001':'2005'])
plot_with_flip_5stages(polt_sma_df['2006':'2008'], rollback_cross['2006':'2008'])
plot_with_flip_5stages(polt_sma_df['2009':'2011'], rollback_cross['2009':'2011'])
plot_with_flip_5stages(polt_sma_df['2012':'2015'], rollback_cross['2012':'2015'])
plot_with_flip_5stages(polt_sma_df['2016':'2021'], rollback_cross['2016':'2021'])


for i in range(int(start), int(end)):
    plot_with_flip_5stages(polt_sma_df[str(i)], rollback_cross[str(i)])"""
# Out:
# "plot_with_flip_5stages(polt_sma_df[start:end], rollback_cross[start:end])\nplot_with_flip_5stages(polt_sma_df['1988':'2000'], rollback_cross['1988':'2000'])\nplot_with_flip_5stages(polt_sma_df['2001':'2005'], rollback_cross['2001':'2005'])\nplot_with_flip_5stages(polt_sma_df['2006':'2008'], rollback_cross['2006':'2008'])\nplot_with_flip_5stages(polt_sma_df['2009':'2011'], rollback_cross['2009':'2011'])\nplot_with_flip_5stages(polt_sma_df['2012':'2015'], rollback_cross['2012':'2015'])\nplot_with_flip_5stages(polt_sma_df['2016':'2021'], rollback_cross['2016':'2021'])\n\n\nfor i in range(int(start), int(end)):\n    plot_with_flip_5stages(polt_sma_df[str(i)], rollback_cross[str(i)])"

# %%
preds = pd.DataFrame(1, columns=['buy_and_hold'], index=true_ret.index)
preds = pd.concat([preds, rollback_cross], axis=1)
preds = preds.fillna(method='ffill')
preds = preds.loc[true_ret.index, :]
# preds = preds['1994': end]
# preds.shape
preds.shape
# Out:
# (10921, 9)

# %%
buy_preds = pd.DataFrame(1, columns=['buy_and_hold'], index=true_ret.index)
for case in rollback_cross.columns:
    for i in range(2, 6):
        buy_preds["{}_buy>={}".format(case, i)] = (preds[case] >= i).astype(int)
buy_preds = buy_preds[start:end]
buy_preds.shape
# Out:
# (9612, 33)

# %%
ret_sma_cross = buy_preds.multiply(true_ret[start:end], 0)
ret_sma_cross.shape
# Out:
# (9612, 33)

# %%
strategy_list_sel = print_all_result(ret_sma_cross, topn=len(ret_sma_cross.columns))
# Out:
# '1985-01-02 00:00:00 to 2021-12-31 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.587703
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.602476
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3         0.526529
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.568352
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.612047
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2         0.612047
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2         0.612047
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.612047
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2         0.612047
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.612047
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.612047
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.612047
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.387953
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3         0.471078
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4         0.471078
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.542551
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.379526
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.516646
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4         0.417707
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3         0.466812
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.371827
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.373700
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4         0.380566
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.340928
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.317000
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.317000
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.317000
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.317000
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.056602  0.511860
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.059099  0.509988
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3    0.049110  0.510196
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.052232  0.510820
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.060348  0.510612
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2    0.060348  0.510612
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2    0.060348  0.510612
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.060348  0.510612
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2    0.060348  0.510612
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.060348  0.510612
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.060348  0.510612
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.060348  0.510612
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.027677  0.505826
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3    0.043908  0.507803
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4    0.043908  0.507803
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.048902  0.513733
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.027260  0.506138
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.045989  0.513629
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4    0.035584  0.509571
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3    0.041619  0.510196
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.026012  0.506346
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.024971  0.507595
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4    0.028301  0.509051
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.017896  0.508947
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.021642  0.507491
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.021642  0.507491
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.021642  0.507491
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.021642  0.507491
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.524518  1.248287
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.522362  1.247869
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3  0.525785  1.248696
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.524437  1.248061
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.522523  1.246155
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2  0.522523  1.246155
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2  0.522523  1.246155
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.522523  1.246155
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2  0.522523  1.246155
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.522523  1.246155
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.522523  1.246155
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.522523  1.246155
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.529364  1.249371
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3  0.526281  1.246989
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4  0.526281  1.246989
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.528284  1.245923
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.530428  1.248270
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.529601  1.244726
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4  0.531756  1.245769
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3  0.529084  1.243995
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.531337  1.246147
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.532851  1.243413
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4  0.534172  1.242587
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.537992  1.242162
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.538563  1.243066
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.538563  1.243066
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.538563  1.243066
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.538563  1.243066
#                                                     annual_return  \
# buy_and_hold                                             0.047776
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.024839
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.025294
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3       0.024755
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.025233
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.027387
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2       0.027387
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2       0.027387
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.027387
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2       0.027387
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.027387
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.027387
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.027387
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.025162
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3       0.027359
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4       0.027359
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.028187
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.026684
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.029890
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4       0.029403
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3       0.031269
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.029467
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.033073
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4       0.033933
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.034982
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5       0.034144
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5       0.034144
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5       0.034144
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.034144
#
#                                                     sharpe_ratio  \
# buy_and_hold                                            0.378081
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.261791
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.264724
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3      0.265240
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.265927
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.280521
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2      0.280521
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2      0.280521
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.280521
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2      0.280521
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.280521
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.280521
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.280521
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.283978
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3      0.291980
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4      0.291980
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.292419
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.299768
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.308627
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4      0.316751
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3      0.326622
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.326737
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.362544
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4      0.366090
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.388055
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      0.388612
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      0.388612
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      0.388612
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.388612
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.493126
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.614867
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.596053
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3     -0.545021
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.547131
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.585587
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2     -0.585587
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2     -0.585587
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.585587
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2     -0.585587
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.585587
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.585587
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.585587
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.398841
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3     -0.468629
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4     -0.468629
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.559027
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.402544
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.503533
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4     -0.435201
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3     -0.454317
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.346755
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.312357
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4     -0.338379
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.293703
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.288825
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.288825
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.288825
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.288825
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.224901      0.212431
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.276292      0.089903
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.256355      0.098667
# phase15_lookback1W_phase234_lookback4W_vote_buy>=3     -0.235070      0.105308
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.242665      0.103982
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback3W_vote_buy>=2     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback4W_vote_buy>=2     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback5W_vote_buy>=2     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.247761      0.110538
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.176189      0.142814
# phase15_lookback1W_phase234_lookback3W_vote_buy>=3     -0.214868      0.127327
# phase15_lookback1W_phase234_lookback3W_vote_buy>=4     -0.214868      0.127327
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.245812      0.114668
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.182732      0.146030
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.207743      0.143878
# phase15_lookback1W_phase234_lookback4W_vote_buy>=4     -0.191320      0.153684
# phase15_lookback1W_phase234_lookback5W_vote_buy>=3     -0.188894      0.165539
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.163109      0.180658
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.138835      0.238220
# phase15_lookback1W_phase234_lookback5W_vote_buy>=4     -0.147200      0.230520
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.128006      0.273283
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.127655      0.267470

# %%
strategy_list_sel = print_all_result(ret_sma_cross)

print_all_result(ret_sma_cross['1988':'2000'], strategy_list_sel=strategy_list_sel)
print_all_result(ret_sma_cross['2001':'2005'], strategy_list_sel=strategy_list_sel)
print_all_result(ret_sma_cross['2006':'2008'], strategy_list_sel=strategy_list_sel)
print_all_result(ret_sma_cross['2009':'2011'], strategy_list_sel=strategy_list_sel)
print_all_result(ret_sma_cross['2012':'2015'], strategy_list_sel=strategy_list_sel)
print_all_result(ret_sma_cross['2016':'2021'], strategy_list_sel=strategy_list_sel)
# Out:
# '1985-01-02 00:00:00 to 2021-12-31 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.340928
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.317000
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.317000
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.317000
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.317000
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.317000
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.017896  0.508947
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.021642  0.507491
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.021642  0.507491
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.021642  0.507491
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.021642  0.507491
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.021642  0.507491
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.537992  1.242162
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.538563  1.243066
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.538563  1.243066
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.538563  1.243066
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.538563  1.243066
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.538563  1.243066
#                                                     annual_return  \
# buy_and_hold                                             0.047776
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.034982
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5       0.034144
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5       0.034144
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5       0.034144
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.034144
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.034144
#
#                                                     sharpe_ratio  \
# buy_and_hold                                            0.378081
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.388055
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      0.388612
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      0.388612
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      0.388612
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.388612
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.388612
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.493126
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.293703
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.288825
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.288825
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.288825
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.288825
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.288825
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.224901      0.212431
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.128006      0.273283
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.127655      0.267470
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.127655      0.267470
# '1988-01-04 00:00:00 to 2000-12-29 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.072803
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.072803
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.072803
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.072803
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.072803
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.072803
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.072803
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.072803
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.072803
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.012729  0.510506
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.012729  0.510506
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.012729  0.510506
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.012729  0.510506
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.012729  0.510506
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.012729  0.510506
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.012729  0.510506
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.012729  0.510506
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.012729  0.510506
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.487805  1.248974
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.487805  1.248974
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.487805  1.248974
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.487805  1.248974
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.487805  1.248974
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.487805  1.248974
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.487805  1.248974
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.487805  1.248974
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.487805  1.248974
#                                                     annual_return  \
# buy_and_hold                                            -0.042235
# phase15_lookback1W_phase234_lookback48W_vote_bu...      -0.017164
# phase15_lookback1W_phase234_lookback24W_vote_bu...      -0.017164
# phase15_lookback1W_phase234_lookback10W_vote_bu...      -0.017164
# phase15_lookback1W_phase234_lookback12W_vote_bu...      -0.017164
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      -0.017164
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      -0.017164
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      -0.017164
# phase15_lookback1W_phase234_lookback15W_vote_bu...      -0.017164
# phase15_lookback1W_phase234_lookback48W_vote_bu...      -0.017164
#
#                                                     sharpe_ratio  \
# buy_and_hold                                           -0.283945
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.462920
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.462920
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.462920
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.462920
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.462920
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.462920
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.462920
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.462920
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.462920
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.481481
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.213218
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.213218
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.213218
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.213218
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.213218
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.213218
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.213218
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.213218
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.213218
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.272448     -0.155021
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.108359     -0.158396
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.108359     -0.158396
# '2001-01-02 00:00:00 to 2005-12-30 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.654112
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.615680
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.615680
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.615680
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.615680
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.615680
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.615680
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.615680
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.615680
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.043846  0.506533
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.049231  0.500384
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.049231  0.500384
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.049231  0.500384
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.049231  0.500384
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.049231  0.500384
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.049231  0.500384
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.049231  0.500384
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.049231  0.500384
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.538190  1.242617
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.535581  1.244607
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.535581  1.244607
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.535581  1.244607
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.535581  1.244607
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.535581  1.244607
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.535581  1.244607
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.535581  1.244607
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.535581  1.244607
#                                                     annual_return  \
# buy_and_hold                                             0.132401
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.074346
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.072385
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.072385
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.072385
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5       0.072385
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5       0.072385
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5       0.072385
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.072385
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.072385
#
#                                                     sharpe_ratio  \
# buy_and_hold                                            0.936292
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.659656
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.661510
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.661510
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.661510
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      0.661510
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      0.661510
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      0.661510
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.661510
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.661510
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.154450
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.146126
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.146126
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.146126
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.146126
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.146126
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.146126
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.146126
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.146126
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.146126
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.042569      3.110238
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.041552      1.789246
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.042598      1.699255
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.042598      1.699255
# '2006-01-03 00:00:00 to 2008-12-31 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.824584
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.722151
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.722151
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.722151
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.722151
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.722151
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.722151
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.722151
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.722151
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.021795  0.517286
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.034615  0.524968
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.034615  0.524968
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.034615  0.524968
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.034615  0.524968
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.034615  0.524968
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.034615  0.524968
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.034615  0.524968
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.034615  0.524968
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.529503  1.226566
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.539007  1.216953
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.539007  1.216953
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.539007  1.216953
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.539007  1.216953
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.539007  1.216953
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.539007  1.216953
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.539007  1.216953
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.539007  1.216953
#                                                     annual_return  \
# buy_and_hold                                             0.186867
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.138214
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.161192
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.161192
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.161192
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5       0.161192
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5       0.161192
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5       0.161192
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.161192
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.161192
#
#                                                     sharpe_ratio  \
# buy_and_hold                                            0.824008
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.760051
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.887650
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.887650
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.887650
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      0.887650
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      0.887650
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      0.887650
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.887650
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.887650
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.290117
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.222369
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.222369
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.222369
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.222369
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.222369
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.222369
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.222369
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.222369
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.222369
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.090528      2.064197
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.096483      1.432516
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.091009      1.771171
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.091009      1.771171
# '2009-01-01 00:00:00 to 2011-12-30 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.765985
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.734015
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.734015
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.734015
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.734015
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.734015
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.734015
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.734015
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.734015
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.014085  0.534527
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.021767  0.523018
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.021767  0.523018
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.021767  0.523018
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.021767  0.523018
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.021767  0.523018
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.021767  0.523018
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.021767  0.523018
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.021767  0.523018
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.559265  1.217192
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.554007  1.230054
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.554007  1.230054
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.554007  1.230054
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.554007  1.230054
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.554007  1.230054
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.554007  1.230054
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.554007  1.230054
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.554007  1.230054
#                                                     annual_return  \
# buy_and_hold                                             0.203590
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.152993
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.132189
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.132189
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.132189
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5       0.132189
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5       0.132189
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5       0.132189
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.132189
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.132189
#
#                                                     sharpe_ratio  \
# buy_and_hold                                            1.084884
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.972003
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.882924
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.882924
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.882924
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      0.882924
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      0.882924
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      0.882924
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.882924
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.882924
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.186157
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.186157
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.186157
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.186157
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.186157
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.186157
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.186157
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.186157
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.186157
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.186157
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.044423      4.583029
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.035405      4.321197
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.029478      4.484409
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.029478      4.484409
# '2012-01-02 00:00:00 to 2015-12-31 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.081574
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.076775
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.076775
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.076775
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.076775
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.076775
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.076775
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.076775
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.076775
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.004803  0.520154
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.002882  0.523033
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.002882  0.523033
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.002882  0.523033
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.002882  0.523033
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.002882  0.523033
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.002882  0.523033
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.002882  0.523033
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.002882  0.523033
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.529412  1.209126
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.550000  1.207138
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.550000  1.207138
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.550000  1.207138
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.550000  1.207138
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.550000  1.207138
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.550000  1.207138
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.550000  1.207138
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.550000  1.207138
#                                                     annual_return  \
# buy_and_hold                                            -0.089555
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.011437
# phase15_lookback1W_phase234_lookback24W_vote_bu...       0.014063
# phase15_lookback1W_phase234_lookback10W_vote_bu...       0.014063
# phase15_lookback1W_phase234_lookback12W_vote_bu...       0.014063
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5       0.014063
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5       0.014063
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5       0.014063
# phase15_lookback1W_phase234_lookback15W_vote_bu...       0.014063
# phase15_lookback1W_phase234_lookback48W_vote_bu...       0.014063
#
#                                                     sharpe_ratio  \
# buy_and_hold                                           -0.494734
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.259116
# phase15_lookback1W_phase234_lookback24W_vote_bu...      0.315631
# phase15_lookback1W_phase234_lookback10W_vote_bu...      0.315631
# phase15_lookback1W_phase234_lookback12W_vote_bu...      0.315631
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      0.315631
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      0.315631
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      0.315631
# phase15_lookback1W_phase234_lookback15W_vote_bu...      0.315631
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.315631
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.412616
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.092740
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.092740
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.092740
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.092740
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.092740
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.092740
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.092740
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.092740
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.092740
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.229167     -0.390783
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.072582      0.157570
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.069042      0.203685
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.069042      0.203685
# '2016-01-01 00:00:00 to 2021-12-31 00:00:00'
#                                                     highlight_ratio  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.313500
# phase15_lookback1W_phase234_lookback24W_vote_bu...         0.271913
# phase15_lookback1W_phase234_lookback10W_vote_bu...         0.271913
# phase15_lookback1W_phase234_lookback12W_vote_bu...         0.271913
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5         0.271913
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5         0.271913
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5         0.271913
# phase15_lookback1W_phase234_lookback15W_vote_bu...         0.271913
# phase15_lookback1W_phase234_lookback48W_vote_bu...         0.271913
#
#                                                     flip_ratio      accu  \
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.014085  0.486884
# phase15_lookback1W_phase234_lookback24W_vote_bu...    0.021767  0.483685
# phase15_lookback1W_phase234_lookback10W_vote_bu...    0.021767  0.483685
# phase15_lookback1W_phase234_lookback12W_vote_bu...    0.021767  0.483685
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5    0.021767  0.483685
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5    0.021767  0.483685
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5    0.021767  0.483685
# phase15_lookback1W_phase234_lookback15W_vote_bu...    0.021767  0.483685
# phase15_lookback1W_phase234_lookback48W_vote_bu...    0.021767  0.483685
#
#                                                         prec       mse
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.536735  1.293464
# phase15_lookback1W_phase234_lookback24W_vote_bu...  0.536471  1.301356
# phase15_lookback1W_phase234_lookback10W_vote_bu...  0.536471  1.301356
# phase15_lookback1W_phase234_lookback12W_vote_bu...  0.536471  1.301356
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5  0.536471  1.301356
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5  0.536471  1.301356
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5  0.536471  1.301356
# phase15_lookback1W_phase234_lookback15W_vote_bu...  0.536471  1.301356
# phase15_lookback1W_phase234_lookback48W_vote_bu...  0.536471  1.301356
#                                                     annual_return  \
# buy_and_hold                                             0.091659
# phase15_lookback1W_phase234_lookback48W_vote_bu...      -0.001171
# phase15_lookback1W_phase234_lookback24W_vote_bu...      -0.009292
# phase15_lookback1W_phase234_lookback10W_vote_bu...      -0.009292
# phase15_lookback1W_phase234_lookback12W_vote_bu...      -0.009292
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5      -0.009292
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5      -0.009292
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5      -0.009292
# phase15_lookback1W_phase234_lookback15W_vote_bu...      -0.009292
# phase15_lookback1W_phase234_lookback48W_vote_bu...      -0.009292
#
#                                                     sharpe_ratio  \
# buy_and_hold                                            0.718013
# phase15_lookback1W_phase234_lookback48W_vote_bu...      0.035584
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.054658
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.054658
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.054658
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.054658
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.054658
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.054658
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.054658
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.054658
#
#                                                     max_drawdown  \
# buy_and_hold                                           -0.185126
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.192137
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.195233
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.195233
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.195233
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.195233
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.195233
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.195233
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.195233
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.195233
#
#                                                     avg_drawdown  return/avgdd
# buy_and_hold                                           -0.066784      1.372467
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.129184     -0.009068
# phase15_lookback1W_phase234_lookback24W_vote_bu...     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback10W_vote_bu...     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback12W_vote_bu...     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback5W_vote_buy>=5     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback4W_vote_buy>=5     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback3W_vote_buy>=5     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback15W_vote_bu...     -0.134956     -0.068850
# phase15_lookback1W_phase234_lookback48W_vote_bu...     -0.134956     -0.068850
# ['buy_and_hold',
#  'phase15_lookback1W_phase234_lookback48W_vote_buy>=4',
#  'phase15_lookback1W_phase234_lookback24W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback10W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback12W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback5W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback4W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback3W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback15W_vote_buy>=5',
#  'phase15_lookback1W_phase234_lookback48W_vote_buy>=5']

# %%
# true_yret_roll_vote_pred
# true_yret_up

acc = pd.Series(index=true_yret_roll_vote_pred.columns)
for col in true_yret_roll_vote_pred.columns:
    acc[col] = accuracy_score(true_yret_up[true_yret_roll_vote_pred.index], true_yret_roll_vote_pred[col])
acc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Sammi\Desktop\Jupyter\gold\phase_5D.ipynb Cell 30' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Sammi/Desktop/Jupyter/gold/phase_5D.ipynb#ch0000029?line=3'>4</a> acc = pd.Series(index=true_yret_roll_vote_pred.columns)
#       <a href='vscode-notebook-cell:/c%3A/Users/Sammi/Desktop/Jupyter/gold/phase_5D.ipynb#ch0000029?line=4'>5</a> for col in true_yret_roll_vote_pred.columns:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sammi/Desktop/Jupyter/gold/phase_5D.ipynb#ch0000029?line=5'>6</a>     acc[col] = accuracy_score(true_yret_up[true_yret_roll_vote_pred.index], true_yret_roll_vote_pred[col])
#       <a href='vscode-notebook-cell:/c%3A/Users/Sammi/Desktop/Jupyter/gold/phase_5D.ipynb#ch0000029?line=6'>7</a> acc
#
# NameError: name 'true_yret_up' is not defined

# %%
true_ret_roll_vote_proba = pd.DataFrame()
lookbacks = [1, 2, 3, 5, 8, 10, 15]
for lookback in lookbacks:
    true_yret_rollN = true_up.astype(int).rolling(lookback*252).mean()
    true_yret_rollN.name = 'lookback{}Y_vote'.format(lookback)
    # print("================================\n", true_yret_rollN)
    true_ret_roll_vote_proba = pd.concat([true_ret_roll_vote_proba, true_yret_rollN], axis=1)

true_ret_roll_vote_proba = true_ret_roll_vote_proba.dropna()
true_ret_roll_vote_proba

# %%
total_return = lambda x: (1+x).prod()-1
true_ret.name = 'true_ret'

lookbacks = [1, 2, 3, 5, 8, 10, 15]
true_yret_roll_ret = pd.DataFrame()
for lookback in lookbacks:
    true_yret_rollN = true_ret.rolling(lookback*252).apply(total_return)
    true_yret_rollN.name = 'lookback{}Y_ret'.format(lookback)
    true_yret_roll_ret = pd.concat([true_yret_roll_ret, true_yret_rollN], axis=1)
true_yret_roll_ret = true_yret_roll_ret.dropna()
true_yret_roll_ret_pred = (true_yret_roll_ret > 0).astype(int).shift().dropna()
# true_yret_roll_ret_pred.index = pd.to_datetime(['{}-01-01'.format(i) for i in true_yret_roll_ret_pred.index])
true_yret_roll_ret_pred

# %%
price[true_yret_roll_ret.index].plot()
plt.show()

for col in true_yret_roll_ret.columns:
    tt = true_yret_roll_ret[col]
    tt.plot(title=col)
    plt.show()

# %%
total_return = lambda x: (1+x).prod()-1
true_yret.name = 'true'

lookbacks = [1, 2, 3, 5, 8, 10, 15]
true_yret_roll_ret = pd.DataFrame()
for lookback in lookbacks:
    true_yret_rollN = true_yret.rolling(lookback).apply(total_return)
    true_yret_rollN.name = 'lookback{}Y_ret'.format(lookback)
    true_yret_roll_ret = pd.concat([true_yret_roll_ret, true_yret_rollN], axis=1)
true_yret_roll_ret = true_yret_roll_ret.dropna()
true_yret_roll_ret_pred = (true_yret_roll_ret > 0).astype(int).shift().dropna()
true_yret_roll_ret_pred.index = pd.to_datetime(['{}-01-01'.format(i) for i in true_yret_roll_ret_pred.index])
true_yret_roll_ret_pred

# %%
preds = pd.DataFrame(1, columns=['buy_and_hold'], index=true_ret.index)
preds = pd.concat([preds, true_yret_roll_ret_pred, true_yret_roll_vote_pred], axis=1)
preds = preds.fillna(method='ffill')
preds = preds.loc[true_ret.index, :]
preds = preds['1994': end]
preds.shape

# %%
ret_sma_cross = preds.multiply(true_ret[preds.index], 0)
ret_sma_cross.shape

# %%
strategy_list_sel = print_all_result(ret_sma_cross)
