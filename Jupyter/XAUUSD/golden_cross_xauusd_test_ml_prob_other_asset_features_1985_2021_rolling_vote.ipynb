# %%
import pandas as pd
import numpy as np
import os
import empyrical as empy

import matplotlib.pyplot as plt
import seaborn as sns



from sklearn.metrics import accuracy_score, precision_score, explained_variance_score, mean_squared_error

# %%
csv = './data/XAU_USD.csv'
start = '1985'
end = '2021'

# %%
name_list = [
    
    'pp5=xgbc(all_index_(EMA_return_all34+dd_vol))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+dd_vol)))',
    'pp5=xgbc(all_index_(EMA_return_all34+dd_vol+excel))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+dd_vol+excel)))',
    'pp5=xgbc(all_index_(EMA_return_all34+dd_vol+excel+excel_cross))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+dd_vol+excel+excel_cross)))',
    'pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol)))',
    'pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel)))',
    'pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross)))',
    
    
    
    
    
    'pp10=xgbc(all_index_(EMA_return_all34+dd_vol))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+dd_vol)))',
    'pp10=xgbc(all_index_(EMA_return_all34+dd_vol+excel))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+dd_vol+excel)))',
    'pp10=xgbc(all_index_(EMA_return_all34+dd_vol+excel+excel_cross))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+dd_vol+excel+excel_cross)))',
    'pp10=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol)))',
    'pp10=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel)))',
    'pp10=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross)))',
    
    
    
    
    'pp21=xgbc(all_index_(EMA_return_all34+dd_vol))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+dd_vol)))',
    'pp21=xgbc(all_index_(EMA_return_all34+dd_vol+excel))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+dd_vol+excel)))',
    'pp21=xgbc(all_index_(EMA_return_all34+dd_vol+excel+excel_cross))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+dd_vol+excel+excel_cross)))',
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol)))',
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel)))',
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross)))',
    
    
    
    
    
    'pp5=xgbc(all_index_(EMA_return_all34+up_dd_volm))',
    'pp5=xgbc(all_index_(EMA_return_all34+up_dd_volm+sd_rsi))',
    'pp5=xgbc(all_index_(EMA_return_all34+up_dd_volm+sd_rsi+excel))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm)))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi)))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi+excel)))',
    
    'pp10=xgbc(all_index_(EMA_return_all34+up_dd_volm))',
    'pp10=xgbc(all_index_(EMA_return_all34+up_dd_volm+sd_rsi))',
    'pp10=xgbc(all_index_(EMA_return_all34+up_dd_volm+sd_rsi+excel))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm)))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi)))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi+excel)))',
    
    'pp21=xgbc(all_index_(EMA_return_all34+up_dd_volm))',
    'pp21=xgbc(all_index_(EMA_return_all34+up_dd_volm+sd_rsi))',
    'pp21=xgbc(all_index_(EMA_return_all34+up_dd_volm+sd_rsi+excel))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm)))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi)))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi+excel)))',
    
    #'pp10=xgbc(EMA_return_all34+TA+price_position)',
    #'pp21=xgbc(EMA_return_all34+TA+price_position)',
    
    'pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA)))',
    'pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel))',
    'pp5=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel)))',
    'pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel+excel_cross))',
    'pp5=xgbc(all_index_(dd_vol))',
    'pp5=xgbc(all_index_(dd_vol+TA))',
    
    
    'pp10=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA)))',
    'pp10=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel)))',
    'pp10=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel+excel_cross))',
    'pp10=xgbc(all_index_(dd_vol))',
    'pp10=xgbc(all_index_(dd_vol+TA))',
    
    
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA)))',
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel)))',
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol+TA+excel+excel_cross))',
    'pp21=xgbc(all_index_(dd_vol))',
    'pp21=xgbc(all_index_(dd_vol+TA))',
    
    
    
    #sammi
    
    'pp5=xgbc(all_xau_(EMA_return_all34))',
    #'pp5=xgbc(all_xau_(EMA_return_all34+dd_vol_ExpandingWindowMA+pct))',
    #'pp5=xgbc(dd_vol_ExpandingWindowMA+pct)',
    'pp5=xgbc(EMA_return_all34)',
    'pp5=xgbc(EMA_return_all34+cross_EMA_price_fib34+TA+price_position)',
    #'pp5=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct)',
    #'pp5=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+excel_cross+price_position)',
    #'pp5=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position)',
    #'pp5=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+price_position)',
    'pp5=xgbc(EMA_return_all34+dd_vol+TA+excel+price_position)',
    'pp5=xgbc(EMA_return_all34+dd_vol+TA+price_position)',
    'pp5=xgbc(EMA_return_all34+TA+price_position)',
    'pp5=xgbc(pca(EMA_return_all34+cross_EMA_price_fib34+TA+price_position))',
    #'pp5=xgbc(pca(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position))',
    #'pp5=xgbc(pca(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+price_position))',
    'pp5=xgbc(pca(EMA_return_all34+dd_vol+TA+price_position))',
    'pp5=xgbc(pca(EMA_return_all34+TA+price_position))',
    'pp5=xgbc(price_position)',
    'pp5=xgbc(TA)',
    'pp5=xgbc(TA+price_position)',
    
    'pp10=xgbc(all_xau_(EMA_return_all34))',
    #'pp10=xgbc(all_xau_(EMA_return_all34+dd_vol_ExpandingWindowMA+pct))',
    #'pp10=xgbc(dd_vol_ExpandingWindowMA+pct)',
    'pp10=xgbc(EMA_return_all34)',
    'pp10=xgbc(EMA_return_all34+cross_EMA_price_fib34+TA+price_position)',
    #'pp10=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct)',
    #'pp10=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+excel_cross+price_position)',
    #'pp10=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position)',
    #'pp10=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+price_position)',
    'pp10=xgbc(EMA_return_all34+dd_vol+TA+excel+price_position)',
    'pp10=xgbc(EMA_return_all34+dd_vol+TA+price_position)',
    'pp10=xgbc(EMA_return_all34+TA+price_position)',
    'pp10=xgbc(pca(EMA_return_all34+cross_EMA_price_fib34+TA+price_position))',
    #'pp10=xgbc(pca(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position))',
    #'pp10=xgbc(pca(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+price_position))',
    'pp10=xgbc(pca(EMA_return_all34+dd_vol+TA+price_position))',
    'pp10=xgbc(pca(EMA_return_all34+TA+price_position))',
    'pp10=xgbc(price_position)',
    'pp10=xgbc(TA)',
    'pp10=xgbc(TA+price_position)',
    
    'pp21=xgbc(all_xau_(EMA_return_all34))',
    #'pp21=xgbc(all_xau_(EMA_return_all34+dd_vol_ExpandingWindowMA+pct))',
    #'pp21=xgbc(dd_vol_ExpandingWindowMA+pct)',
    'pp21=xgbc(EMA_return_all34)',
    'pp21=xgbc(EMA_return_all34+cross_EMA_price_fib34+TA+price_position)',
    #'pp21=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct)',
    #'pp21=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+excel_cross+price_position)',
    #'pp21=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position)',
    #'pp21=xgbc(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+price_position)',
    'pp21=xgbc(EMA_return_all34+dd_vol+TA+excel+price_position)',
    'pp21=xgbc(EMA_return_all34+dd_vol+TA+price_position)',
    'pp21=xgbc(EMA_return_all34+TA+price_position)',
    'pp21=xgbc(pca(EMA_return_all34+cross_EMA_price_fib34+TA+price_position))',
    #'pp21=xgbc(pca(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position))',
    #'pp21=xgbc(pca(EMA_return_all34+dd_vol_ExpandingWindowMA+pct+TA+price_position))',
    'pp21=xgbc(pca(EMA_return_all34+dd_vol+TA+price_position))',
    'pp21=xgbc(pca(EMA_return_all34+TA+price_position))',
    'pp21=xgbc(price_position)',
    'pp21=xgbc(TA)',
    'pp21=xgbc(TA+price_position)',
    

    
    
    
    
    #'pred_vote_crossema_4xgb',
    #'pred_vote_crossema_6xgb',
    
]

file_list = [
    
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+excel))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+excel)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+excel+excel_cross))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+excel+excel_cross)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel+excel_cross))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel+excel_cross)))___1981___2021___XAU_USD.csv',
    
    
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+excel))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+excel)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+excel+excel_cross))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+excel+excel_cross)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel+excel_cross))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel+excel_cross)))___1981___2021___XAU_USD.csv',
    
    
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+excel))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+excel)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+excel+excel_cross))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+excel+excel_cross)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel)))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel+excel_cross))___1981___2021___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+excel+excel_cross)))___1981___2021___XAU_USD.csv',
    
    
    
    
    
    
    
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+TA)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+TA+excel)))___1981___2022___XAU_USD.csv',
    
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+TA)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+TA+excel)))___1981___2022___XAU_USD.csv',
    
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+TA)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+dd_vol+TA+excel)))___1981___2022___XAU_USD.csv',
    
    
    #'output_all/pred___pp10=xgbc(EMA_return_all_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(EMA_return_all_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    
    
    
    # 20220425
    
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel+excel_cross))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol+TA))___1981___2022___XAU_USD.csv',
    
    
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel+excel_cross))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol+TA))___1981___2022___XAU_USD.csv',
    
    
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel)))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel+excel_cross))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol+TA))___1981___2022___XAU_USD.csv',
    
    # sammi 20220425
    
    'output_all/pred___pp5=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(dd_vol_ExpandingWindowMA+pct)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(EMA_return_all_1_34)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(EMA_return_all_1_34+cross_EMA_price_fib_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+excel_cross+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(EMA_return_all_1_34+dd_vol+TA+excel+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(EMA_return_all_1_34+dd_vol+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(EMA_return_all_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+TA+price_position))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(pca(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp5=xgbc(pca(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(pca(EMA_return_all_1_34+dd_vol+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(pca(EMA_return_all_1_34+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(TA)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp5=xgbc(TA+price_position)___1981___2022___XAU_USD.csv',
    
    'output_all/pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(dd_vol_ExpandingWindowMA+pct)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(EMA_return_all_1_34)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(EMA_return_all_1_34+cross_EMA_price_fib_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+excel_cross+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(EMA_return_all_1_34+dd_vol+TA+excel+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(EMA_return_all_1_34+dd_vol+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(EMA_return_all_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+TA+price_position))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(pca(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp10=xgbc(pca(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(pca(EMA_return_all_1_34+dd_vol+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(pca(EMA_return_all_1_34+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(TA)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp10=xgbc(TA+price_position)___1981___2022___XAU_USD.csv',
    
    'output_all/pred___pp21=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(dd_vol_ExpandingWindowMA+pct)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(EMA_return_all_1_34)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(EMA_return_all_1_34+cross_EMA_price_fib_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+excel_cross+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position)___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(EMA_return_all_1_34+dd_vol+TA+excel+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(EMA_return_all_1_34+dd_vol+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(EMA_return_all_1_34+TA+price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+TA+price_position))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(pca(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+excel+price_position))___1981___2022___XAU_USD.csv',
    #'output_all/pred___pp21=xgbc(pca(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(pca(EMA_return_all_1_34+dd_vol+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(pca(EMA_return_all_1_34+TA+price_position))___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(price_position)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(TA)___1981___2022___XAU_USD.csv',
    'output_all/pred___pp21=xgbc(TA+price_position)___1981___2022___XAU_USD.csv',



    

    
    #'pred_vote_crossema_4xgb.csv',
    #'pred_vote_crossema_6xgb.csv',
    
    
]

# %%
folder = './output_all'

file_list = []
name_list = []
for fn in os.listdir(folder):
    if not fn.startswith("pred___pp"):
        continue
    file_list.append(os.path.join(folder, fn))
    fn.replace("pred___", "")
    fn.replace(".csv", "")
    name_list.append(fn)
len(file_list)
# Out:
# 105

# %%
len(name_list)
# Out:
# 105

# %%
name_list
# Out:
# ['pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34))___1981___2022___XAU_USD.csv',
#  'pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_EUR+XAU_JPY)_(EMA_return_all_1_34+dd_vol_ExpandingWindowMA+pct))___1981___2022___XAU_USD.csv',
#  'pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol))___1981___2022___XAU_USD.csv',
#  'pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(dd_vol+TA))___1981___2022___XAU_USD.csv',
#  'pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA))___1981___2022___XAU_USD.csv',
#  'pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel))___1981___2022___XAU_USD.csv',
#  'pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JPYUSD=X+^GSPC+^VIX)_(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol+TA+excel+excel_cross))___1981___2022___XAU_USD.csv',
# ...

# %%
def print_clustermap(data, title='', figsize=(12,12)):
    
    corr = data.corr()
    '''data_clean = data.applymap(lambda x: x if x!=0 else np.nan)
    for n in ['Growth','Mod','FICon','Con']:
        data_clean[n] = data_clean[n].fillna(0)
    corr = data_clean.corr()
    '''
    g = sns.clustermap(corr, method="complete", cmap='PuOr', annot=True, 
                   annot_kws={"size": 10}, vmin=-1, vmax=1, figsize=figsize)
    g.fig.suptitle(title)
    plt.show()

# %%
def drawdown_from_price(price):
    if isinstance(price, pd.Series):
        return _drawdown_from_price(price)
    elif isinstance(price, pd.DataFrame):
        return price.apply(_drawdown_from_price)
    else:
        raise non_pd_error

def _drawdown_from_price(price):
    shift_max = price.copy()
    _max = price.iloc[0]
    for i, j in price.items():
        #print('i', i)
        #print('j', j)
        _max = max(_max, j)
        shift_max[i] = _max
    return price / shift_max - 1

def return_to_price(ret, ini=100):
    price_0 = ret.iloc[:1] * 0 + ini
    price_0.index = [0]
    price = (1+ret).cumprod() * ini
    return pd.concat([price_0, price])

def drawdown_from_return(ret, ini=100):
    price = return_to_price(ret, ini)
    return drawdown_from_price(price).iloc[1:]

def avg_drawdown(ret):
    dd = drawdown_from_return(ret)
    return dd.mean()

# %%
def empy_metric(ret):
    if isinstance(ret, pd.DataFrame):
        return ret.apply(empy_metric).T
    total_return = lambda x: (1+x).prod()-1
    met_func = [total_return, empy.annual_return, empy.sharpe_ratio, empy.annual_volatility, 
                empy.max_drawdown, avg_drawdown]
    
    met_func_names = ['total_return', 'annual_return', 'sharpe_ratio', 'annual_volatility', 
                      'max_drawdown', 'avg_drawdown',]
    
    se = pd.Series([f(ret) for f in met_func], met_func_names)
    
    se['return/maxdd'] = -se.annual_return/se.max_drawdown
    se['return/avgdd'] = -se.annual_return/se.avg_drawdown
    
    return se

# %%
def predict_freq(pred, freq='M'):
    
    #print(pred)
    #print(pred[pred.index.duplicated()])
    
    idx = pred.index.to_series()
    idx_m = idx.groupby(pd.Grouper(freq=freq)).first()
    pred_m = pred.groupby(pd.Grouper(freq=freq)).first()
    pred_m.index = idx_m
    
    #print(idx)
    #print(idx[idx.index.duplicated()])
    #print(pred_m)
    #print(pred_m[pred_m.index.duplicated()])
    
    pred_m = pred_m.dropna().reindex(idx).ffill()
    
    return pred_m

# %%
sma = lambda x, y: x.rolling(int(y)).mean()

ewma = lambda x, y: x.ewm(span=y).mean()

def s(x,x0,x1,y0=0,y1=1,d=np.nan):
    if x>=x1:
        return y1
    if x<x0:
        return y0
    return d

# %%
"""def predict_cont_n(pred, n):
    
    pred_ewma = ewma(pred, 3)
    
    lb = 2**(-n)
    ub = 1-lb
    
    pred_cont_n = pred_ewma.apply(lambda x: s(x, lb, ub))
    
    pred_cont_n = pred_cont_n.ffill().fillna(1)
    
    return pred_cont_n
"""
# Out:
# 'def predict_cont_n(pred, n):\n    \n    pred_ewma = ewma(pred, 3)\n    \n    lb = 2**(-n)\n    ub = 1-lb\n    \n    pred_cont_n = pred_ewma.apply(lambda x: s(x, lb, ub))\n    \n    pred_cont_n = pred_cont_n.ffill().fillna(1)\n    \n    return pred_cont_n\n'

# %%
def exp_sum(se):
    _sum = 0
    for i,v in enumerate(se):
        _sum += v*(2**i)
    return _sum
def cont_n_01(x, n):
    if x <= 0:
        return 0
    if x >= 2**n - 1:
        return 1
    return np.nan
def predict_cont_n(vote, n, rb_lookback=True):
    if not rb_lookback:
        v_tmp = vote.groupby(pd.Grouper(freq='M')).apply(lambda x: predict_cont_n(x, n)).values
        return pd.Series(v_tmp, index=vote.index)
    vres = vote.rolling(n).apply(lambda x: exp_sum(x))
    vote_c = vres.apply(lambda x: cont_n_01(x, n))
    if np.isnan(vote_c.iloc[0]):
        vote_c.iloc[0] = vote.iloc[0]
    vote_c = vote_c.ffill()
    return vote_c

# %%
price = pd.read_csv(csv, index_col=0)['adj_close']
price.index = pd.to_datetime(price.index)
price[start:end].plot()

# %%
true_ret = price.pct_change()
true_ret = true_ret[start:end]
true_ret
# Out:
# date
# 1985-01-02   -0.009082
# 1985-01-03   -0.010475
# 1985-01-04    0.002646
# 1985-01-07   -0.016166
# 1985-01-08    0.012743
#                 ...
# 2021-12-27    0.001543
# 2021-12-28   -0.003054
# 2021-12-29   -0.000947
# 2021-12-30    0.006293
# 2021-12-31    0.007372
# Name: adj_close, Length: 9612, dtype: float64

# %%
true_up = (true_ret>=0)
true_up
# Out:
# date
# 1985-01-02    False
# 1985-01-03    False
# 1985-01-04     True
# 1985-01-07    False
# 1985-01-08     True
#               ...
# 2021-12-27     True
# 2021-12-28    False
# 2021-12-29    False
# 2021-12-30     True
# 2021-12-31     True
# Name: adj_close, Length: 9612, dtype: bool

# %%
def other_metric(ret):
    if isinstance(ret, pd.DataFrame):
        return ret.apply(other_metric).T
    
    pred_up = (ret!=0)*1
    
    highlight_ratio = pred_up.mean()
    flip_ratio = (pred_up - pred_up.shift()).abs().mean()
    
    idx_tmp = pred_up.index & true_up.index
    true_up_tmp = true_up.reindex(idx_tmp) * 1
    pred_up = pred_up.reindex(idx_tmp) * 1
    accu = accuracy_score(true_up_tmp, pred_up)
    prec = precision_score(true_up_tmp, pred_up)
    
    true_up_pct = true_ret.reindex(idx_tmp)
    true_up_pct_scaled = true_up_pct/true_up_pct.std() + 0.5
    
    mse = mean_squared_error(true_up_pct_scaled, pred_up)
    
    se = pd.Series(dtype='float64')
    
    se['highlight_ratio'] = highlight_ratio
    se['flip_ratio'] = flip_ratio
    se['accu'] = accu
    se['prec'] = prec
    se['mse'] = mse
    
    return se

# %%
def ret_short_once_every_interval(ret, shorting_interval):
    
    ret_short = ret.copy()
    
    t_prev = ret.index[0]
    cum_prod_prev = 1
    t_start_short = ret.index[0]
    cum_prod = 1
    
    for t in ret.index[1:]:
        if shorting_interval[t]:
            if not shorting_interval[t_prev]:
                t_start_short = t
                
            cum_prod = 2 - (1+ret[t_start_short:t]).prod()
            if cum_prod <= 0:
                ret_short[t:] = 0
                ret_short[t] = -1
                
                print('t_start_short', t_start_short)
                print('price', price[t_start_short])
                print('t', t)
                print('price', price[t])
                
                print('broke on', t)
                
                break
            ret_short[t] = cum_prod / cum_prod_prev - 1
                
                
        else:
            cum_prod = 1
        
        t_prev = t
        cum_prod_prev = cum_prod
    
    return ret_short

# %%
true_ret
# Out:
# date
# 1985-01-02   -0.009082
# 1985-01-03   -0.010475
# 1985-01-04    0.002646
# 1985-01-07   -0.016166
# 1985-01-08    0.012743
#                 ...
# 2021-12-27    0.001543
# 2021-12-28   -0.003054
# 2021-12-29   -0.000947
# 2021-12-30    0.006293
# 2021-12-31    0.007372
# Name: adj_close, Length: 9612, dtype: float64

# %%
'''highlight = price.index[fast_indicator>slow_indicator]
shorting_interval = pd.Series(ret.index.isin(highlight), ret.index)
shorting_interval'''
# Out:
# 'highlight = price.index[fast_indicator>slow_indicator]\nshorting_interval = pd.Series(ret.index.isin(highlight), ret.index)\nshorting_interval'

# %%
'''shorting_interval[~shorting_interval]'''
# Out:
# 'shorting_interval[~shorting_interval]'

# %%
'''ret_short_once = ret_short_once_every_interval(ret, shorting_interval)
ret_short_once'''
# Out:
# 'ret_short_once = ret_short_once_every_interval(ret, shorting_interval)\nret_short_once'

# %%
def sim_indicator(pred_up, name, plot=False):
    
    pred_up = pred_up.reindex(true_ret.index).ffill()
    
    indicator = pred_up[pred_up==1].index
    
    
    ret_df = pd.DataFrame()

    #ret_df['buy_and_hold'] = ret[start:]

    ret_i = true_ret.copy()
    ret_i.loc[~ret_i.index.isin(indicator)] = 0
    ret_df['hold_only_pred_up_{}'.format(name)] = ret_i
    
    #highlight_ratio = ret_i.apply(lambda x: 1 if x!=0 else 0).mean()
    
    highlight_ratio = pred_up.mean()
    flip_ratio = (pred_up - pred_up.shift()).abs().mean()
    
    
    
    #print('highlight_ratio', highlight_ratio)
    #print('flip_ratio', flip_ratio)
    
    
    empy_met = empy_metric(ret_df)
    
    
    other_met = other_metric(ret_df)
    
    """
    for k in [5,10,21]:
        pct_change = (price.shift(1-k) - price.shift(1))/price.shift(1)
        pct_change = pct_change.reindex(idx_tmp)
        true_up_k = (pct_change>=0)*1
        other_met['accu{}'.format(k)] = [accuracy_score(true_up_k, pred_up)]
        other_met['prec{}'.format(k)] = [precision_score(true_up_k, pred_up)]
        
        #true_up_pct_scaled = (pct_change-pct_change.min())/(pct_change.max()-pct_change.min())
        true_up_pct_scaled = pct_change/pct_change.std() + 0.5
        #other_met['expvar{}'.format(k)] = [explained_variance_score(true_up_pct_scaled, pred_up)]
        other_met['mse{}'.format(k)] = [mean_squared_error(true_up_pct_scaled, pred_up)]
        
    """
    
    if plot:
        fig, ax = plt.subplots()
        (1+ret_df).cumprod().plot(ax=ax)
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        ax.set_yscale("log")
        plt.show()
    
    res = {}
    res['ret_df'] = ret_df
    res['empy_metric'] = empy_met
    res['other_metric'] = other_met
    
    return res

# %%
def sim_indicator_prob(prob_up, name, plot=False):
    
    #indicator = pred_up[pred_up==1].index
    
    
    ret_df = pd.DataFrame()

    #ret_df['buy_and_hold'] = ret[start:]

    ret_i = ret[start:end].copy()
    #ret_i.loc[~ret_i.index.isin(indicator)] = 0
    ret_df['hold_only_pred_up_{}'.format(name)] = ret_i*prob_up[start:end]
    
    #highlight_ratio = ret_i.apply(lambda x: 1 if x!=0 else 0).mean()
    
    highlight_ratio = prob_up.mean()
    #flip_ratio = (pred_up - pred_up.shift()).abs().mean()
    flip_ratio = (prob_up - prob_up.shift()).abs().mean()
    
    
    
    #print('highlight_ratio', highlight_ratio)
    #print('flip_ratio', flip_ratio)
    
    
    empy_met = empy_metric(ret_df)
    
    pred_up = prob_up.apply(lambda x: 0 if x<0.5 else 1)
    
    
    true_up = (ret[start:]>=0).dropna()
    idx_tmp = pred_up.index & true_up.index
    true_up = true_up.reindex(idx_tmp) * 1
    pred_up = pred_up.reindex(idx_tmp) * 1
    prob_up = prob_up.reindex(idx_tmp) * 1
    accu = accuracy_score(true_up, pred_up)
    prec = precision_score(true_up, pred_up)
    '''
    true_up21 = (price.shift(-20) - price.shift(1))>=0
    true_up21 = true_up21.reindex(idx_tmp) * 1
    accu21 = accuracy_score(true_up21, pred_up)
    '''
    
    true_up_pct = ret.reindex(idx_tmp)
    #true_up_pct_scaled = (true_up_pct-true_up_pct.min())/(true_up_pct.max()-true_up_pct.min())
    true_up_pct_scaled = true_up_pct/true_up_pct.std() + 0.5
    
    expvar = explained_variance_score(true_up_pct_scaled, prob_up)
    mse = mean_squared_error(true_up_pct_scaled, prob_up)
    
    
    other_met = pd.DataFrame()
    other_met['highlight_ratio'] = [highlight_ratio]
    other_met['flip_ratio'] = [flip_ratio]
    other_met['accu'] = [accu]
    other_met['prec'] = [prec]
    other_met['expvar'] = [expvar]
    other_met['mse'] = [mse]
    
    
    #other_met['accu21'] = [accu21]
    
    for k in [5,10,21]:
        pct_change = (price.shift(1-k) - price.shift(1))/price.shift(1)
        pct_change = pct_change.reindex(idx_tmp)
        true_up_k = (pct_change>=0)*1
        other_met['accu{}'.format(k)] = [accuracy_score(true_up_k, pred_up)]
        other_met['prec{}'.format(k)] = [precision_score(true_up_k, pred_up)]
        
        #true_up_pct_scaled = (pct_change-pct_change.min())/(pct_change.max()-pct_change.min())
        true_up_pct_scaled = pct_change/pct_change.std() + 0.5
        other_met['expvar{}'.format(k)] = [explained_variance_score(true_up_pct_scaled, prob_up)]
        other_met['mse{}'.format(k)] = [mean_squared_error(true_up_pct_scaled, prob_up)]
        
    
    
    
    
    
    #other_met['accu'] = [accu]
    #other_met['accu21'] = [accu21]
    
    #display(empy_met)
    
    if plot:
        fig, ax = plt.subplots()
        (1+ret_df).cumprod().plot(ax=ax)
        ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        ax.set_yscale("log")
        plt.show()
    
    res = {}
    res['ret_df'] = ret_df
    res['empy_metric'] = empy_met
    res['other_metric'] = other_met
    
    return res

# %%
"""def sim_fast_slow_indicator(fast_indicator, slow_indicator, indicator_name_list):

    tempdf = pd.concat([fast_indicator, slow_indicator], 1, keys=indicator_name_list)
    
    
    #fig, axs = plt.subplots(2, figsize=(12,12))
    #tempdf.plot(ax=axs[0])
    #axs[0].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    
    highlight = price[start:].index[fast_indicator>slow_indicator]
    highlight_str = '{}>{}'.format(
        indicator_name_list[0],
        indicator_name_list[1])
    non_highlight_str = '{}<{}'.format(
        indicator_name_list[0],
        indicator_name_list[1])
    
    
    
    ret_df = pd.DataFrame()

    ret_df['buy_and_hold_{}_{}'.format(*indicator_name_list)] = ret[start:]

    ret_i = ret[start:].copy()
    ret_i.loc[~ret_i.index.isin(highlight)] = 0
    ret_df['hold_only_{}'.format(highlight_str)] = ret_i
    
    '''
    ret_j = ret[start:].copy()
    ret_j.loc[ret_j.index.isin(highlight)] = 0
    ret_df['hold_only_{}'.format(non_highlight_str)] = ret_j
    '''
    
    
    '''
    ret_k = ret[start:].copy()
    ret_k.loc[~ret_k.index.isin(highlight)] = -ret_k.loc[~ret_k.index.isin(highlight)]
    ret_df['long_highlight__short_daily_non_highlight'] = ret_k
    
    ret_df['short_daily_highlight__long_non_highlight'] = -ret_k
    
    
    ret_s = ret[start:].copy()
    shorting_interval = ~ret.index.isin(highlight)
    shorting_interval_seri = pd.Series(shorting_interval, ret.index)
    ret_short = ret_short_once_every_interval(ret_s, shorting_interval_seri)
    ret_df['long_highlight__short_non_highlight'] = ret_short
    
    
    ret_s = ret[start:].copy()
    shorting_interval = ret.index.isin(highlight)
    shorting_interval_seri = pd.Series(shorting_interval, ret.index)
    ret_short = ret_short_once_every_interval(ret_s, shorting_interval_seri)
    ret_df['short_highlight__long_non_highlight'] = ret_short
    
    '''
    
    
    #(1+ret_df).cumprod().plot(ax=axs[1])
    #axs[1].legend(loc='center left', bbox_to_anchor=(1, 0.5))
    #axs[1].set_yscale("log")
    
    highlight_ratio = ret_i.apply(lambda x: 1 if x!=0 else 0).mean()
    print('pred_up_ratio', highlight_ratio)
    empy_met = empy_metric(ret_df)
    display(empy_met)
    
    #plt.show()
    
    res = {}
    res['ret_df'] = ret_df
    res['empy_metric'] = empy_met
    
    return res"""
# Out:
# 'def sim_fast_slow_indicator(fast_indicator, slow_indicator, indicator_name_list):\n\n    tempdf = pd.concat([fast_indicator, slow_indicator], 1, keys=indicator_name_list)\n    \n    \n    #fig, axs = plt.subplots(2, figsize=(12,12))\n    #tempdf.plot(ax=axs[0])\n    #axs[0].legend(loc=\'center left\', bbox_to_anchor=(1, 0.5))\n    \n    \n    highlight = price[start:].index[fast_indicator>slow_indicator]\n    highlight_str = \'{}>{}\'.format(\n        indicator_name_list[0],\n        indicator_name_list[1])\n    non_highlight_str = \'{}<{}\'.format(\n        indicator_name_list[0],\n        indicator_name_list[1])\n    \n    \n    \n    ret_df = pd.DataFrame()\n\n    ret_df[\'buy_and_hold_{}_{}\'.format(*indicator_name_list)] = ret[start:]\n\n    ret_i = ret[start:].copy()\n    ret_i.loc[~ret_i.index.isin(highlight)] = 0\n    ret_df[\'hold_only_{}\'.format(highlight_str)] = ret_i\n    \n    \'\'\'\n    ret_j = ret[start:].copy()\n    ret_j.loc[ret_j.index.isin(highlight)] = 0\n    r
# ...

# %%
'''ld = [1, 2, 5, 8, 13, 21, 34, 55, 89, 144, 288]
lm = [l*21 for l in ld]
ll = ld+lm
ll.sort()
ll = [l for l in ll if l<1000]
'''
# Out:
# 'ld = [1, 2, 5, 8, 13, 21, 34, 55, 89, 144, 288]\nlm = [l*21 for l in ld]\nll = ld+lm\nll.sort()\nll = [l for l in ll if l<1000]\n'

# %%
#ll = [1, 2, 5, 8]

# %%
pred_all = pd.DataFrame()
prob_all = {}
result_all = {}

for name, csv in zip(name_list, file_list):
    
    #display(name)
    try:
        pred_df = pd.read_csv(csv.format(name), index_col=0)
    except:
        print('no file [{}]'.format(csv))
        continue
    
    pred_df.index = pd.to_datetime(pred_df.index)
    
    pred_up = pred_df['y_pred']
    prob_up = pred_df['y_prob']
    
    
    
    
    
    #print('flip_ratio', (pred_up - pred_up.shift()).abs().mean())
    
    #indicator = pred_up[pred_up==1].index
    
    
    pred_all[name] = pred_up
    result_all[name] = sim_indicator(pred_up, name)
    
    
    """
    for f in ['5D', '10D', '21D', 'W', '2W', 'M']:
        name_f = name+'_freq_'+f
        pred_all[name_f] = predict_freq(pred_up, freq=f)
        result_all[name_f] = sim_indicator(pred_all[name_f], name_f)
        
    
    #for n in [2,3,4,5]:
    for n in range(2,22):
        name_c = name+'_cont_'+str(n)+'_rb_lookback'
        pred_all[name_c] = predict_cont_n(pred_up, n, rb_lookback=True)
        result_all[name_c] = sim_indicator(pred_all[name_c], name_c)
        
        name_c = name+'_cont_'+str(n)+'_rb_follow'
        pred_all[name_c] = predict_cont_n(pred_up, n, rb_lookback=False)
        result_all[name_c] = sim_indicator(pred_all[name_c], name_c)
        
    """
        
        
    '''
    prob_all[name] = prob_up
    
    name_prob = name+'_prob'
    
    result_all[name_prob] = sim_indicator_prob(prob_up, name_prob)
    
    for f in ['5D', '10D', '21D', 'W', '2W', 'M']:
        name_f = name_prob+'_freq_'+f
        prob_all[name_f] = predict_freq(prob_up, freq=f)
        result_all[name_f] = sim_indicator_prob(prob_all[name_f], name_f)
        
    
    for n in [1,2,3,4,5]:
        name_c = name_prob+'_cont_'+str(n)
        prob_all[name_c] = predict_cont_n(prob_up, n)
        result_all[name_c] = sim_indicator_prob(prob_all[name_c], name_c)
    
    '''
pred_all['buy_and_hold'] = 1

# %%
"""name = 'ema_all_1_34_return___cross_ema_all_1_34_price___5D___vote_a'

vote_list = [
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set1',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set2',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set3',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set4',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set5',
]

pred_up = pd.concat([pred_all[n] for n in vote_list], 1).mean(1).apply(lambda x: s(x, 0.5, 0.5))
pred_all[name] = pred_up
result_all[name] = sim_indicator(pred_up, name)
    
for f in ['10D', '21D', 'M']:
    name_f = name+'_freq_'+f
    pred_all[name_f] = predict_freq(pred_up, freq=f)
    result_all[name_f] = sim_indicator(pred_all[name_f], name_f)
        
for n in [2,3,4,5]:
    name_c = name+'_cont_'+str(n)
    pred_all[name_c] = predict_cont_n(pred_up, n)
    result_all[name_c] = sim_indicator(pred_all[name_c], name_c)
        """
# Out:
# "name = 'ema_all_1_34_return___cross_ema_all_1_34_price___5D___vote_a'\n\nvote_list = [\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set1',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set2',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set3',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set4',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___set5',\n]\n\npred_up = pd.concat([pred_all[n] for n in vote_list], 1).mean(1).apply(lambda x: s(x, 0.5, 0.5))\npred_all[name] = pred_up\nresult_all[name] = sim_indicator(pred_up, name)\n    \nfor f in ['10D', '21D', 'M']:\n    name_f = name+'_freq_'+f\n    pred_all[name_f] = predict_freq(pred_up, freq=f)\n    result_all[name_f] = sim_indicator(pred_all[name_f], name_f)\n        \nfor n in [2,3,4,5]:\n    name_c = name+'_cont_'+str(n)\n    pred_all[name_c] = predict_cont_n(pred_up, n)\n    result_all[name_c] = sim_indicator(pred_all[name_c], name_c)\n        "

# %%
"""name = 'ema_all_1_34_return___cross_ema_all_1_34_price___5D___vote_b'

vote_list = [
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff1',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff2',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff3',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff4',
    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff5',
]

pred_up = pd.concat([pred_all[n] for n in vote_list], 1).mean(1).apply(lambda x: s(x, 0.5, 0.5))
pred_all[name] = pred_up
result_all[name] = sim_indicator(pred_up, name)
    
for f in ['10D', '21D', 'M']:
    name_f = name+'_freq_'+f
    pred_all[name_f] = predict_freq(pred_up, freq=f)
    result_all[name_f] = sim_indicator(pred_all[name_f], name_f)
        
for n in [2,3,4,5]:
    name_c = name+'_cont_'+str(n)
    pred_all[name_c] = predict_cont_n(pred_up, n)
    result_all[name_c] = sim_indicator(pred_all[name_c], name_c)
        """
# Out:
# "name = 'ema_all_1_34_return___cross_ema_all_1_34_price___5D___vote_b'\n\nvote_list = [\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff1',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff2',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff3',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff4',\n    'ema_all_1_34_return___cross_ema_all_1_34_price___5D___fff5',\n]\n\npred_up = pd.concat([pred_all[n] for n in vote_list], 1).mean(1).apply(lambda x: s(x, 0.5, 0.5))\npred_all[name] = pred_up\nresult_all[name] = sim_indicator(pred_up, name)\n    \nfor f in ['10D', '21D', 'M']:\n    name_f = name+'_freq_'+f\n    pred_all[name_f] = predict_freq(pred_up, freq=f)\n    result_all[name_f] = sim_indicator(pred_all[name_f], name_f)\n        \nfor n in [2,3,4,5]:\n    name_c = name+'_cont_'+str(n)\n    pred_all[name_c] = predict_cont_n(pred_up, n)\n    result_all[name_c] = sim_indicator(pred_all[name_c], name_c)\n        "

# %%
name_list = []
se_list = []
name_list.append('buy_and_hold')
se_list.append(empy_metric(true_ret))

for name, r in result_all.items():
    #print(name)
    #print(r['empy_metric'])
    #empy_metric_all[name] = r['empy_metric'].iloc[0]
    name_list.append(name)
    se_list.append(r['empy_metric'].iloc[0])

    
empy_metric_all = pd.concat(se_list, 1, keys=name_list).T
display(empy_metric_all)
# Out:
#                                                     total_return  \
# buy_and_hold                                            4.930555
# pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_E...      1.311995
# pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_E...    347.824637
# pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JP...      1.135778
# pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JP...      0.687886
# ...                                                          ...
# pred___pp5=xgbc(pca(EMA_return_all_1_34+dd_vol_...    217.261653
# pred___pp5=xgbc(pca(EMA_return_all_1_34+TA+pric...     -0.022479
# pred___pp5=xgbc(price_position)___1981___2022__...      1.440244
# pred___pp5=xgbc(TA)___1981___2022___XAU_USD.csv         0.180290
# pred___pp5=xgbc(TA+price_position)___1981___202...      0.429181
#
#                                                     annual_return  \
# buy_and_hold                                             0.047776
# ...

# %%
name_list = []
se_list = []

for name, r in result_all.items():
    #print(name)
    #print(r['empy_metric'])
    #empy_metric_all[name] = r['empy_metric'].iloc[0]
    name_list.append(name)
    se_list.append(r['other_metric'].iloc[0])

    
other_metric_all = pd.concat(se_list, 1, keys=name_list).T

other_metric_all.loc['buy_and_hold'] = 0

display(other_metric_all)
# Out:
#                                                     highlight_ratio  \
# pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_E...         0.409384
# pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_E...         0.485747
# pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JP...         0.454952
# pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JP...         0.487308
# pred___pp10=xgbc((XAU_USD+^GVZ+SI=F+EURUSD=X+JP...         0.490012
# ...                                                             ...
# pred___pp5=xgbc(pca(EMA_return_all_1_34+TA+pric...         0.449438
# pred___pp5=xgbc(price_position)___1981___2022__...         0.307220
# pred___pp5=xgbc(TA)___1981___2022___XAU_USD.csv            0.459010
# pred___pp5=xgbc(TA+price_position)___1981___202...         0.441323
# buy_and_hold                                               0.000000
#
#                                                     flip_ratio      accu  \
# pred___pp10=xgbc((XAU_USD+XAU_AUD+XAU_CNY+XAU_E...    0.180106  0.497919
# ...

# %%
ret_all = pd.DataFrame()
ret_all['buy_and_hold'] = true_ret


for name, r in result_all.items():
    #print(name)
    #print(r['empy_metric'])
    ret_all[name] = r['ret_df'].iloc[:,0]

    
    
"""
fig, ax = plt.subplots(figsize=(12,6))
(1+ret_all).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
"""
# Out:
# '\nfig, ax = plt.subplots(figsize=(12,6))\n(1+ret_all).cumprod().plot(ax=ax)\nax.legend(loc=\'center left\', bbox_to_anchor=(1, 0.5))\nax.set_yscale("log")\n'

# %%
'''preds_summary = pd.read_csv('preds_summary.csv', index_col=0)
preds_summary'''
# Out:
# "preds_summary = pd.read_csv('preds_summary.csv', index_col=0)\npreds_summary"

# %%
'''(preds_summary - preds_summary.shift()).abs().mean().sort_values().plot()'''
# Out:
# '(preds_summary - preds_summary.shift()).abs().mean().sort_values().plot()'

# %%
'''

for name in preds_summary.columns:
    
    display(name)
    
    pred_up = preds_summary[name]
    pred_up.index = pd.to_datetime(pred_up.index)
    
    print('flip ratio', (pred_up - pred_up.shift()).abs().mean())
    
    # indicator = pred_up[pred_up==1].index
    
    res = sim_indicator(pred_up, name)
    result_all[name] = res'''
# Out:
# "\n\nfor name in preds_summary.columns:\n    \n    display(name)\n    \n    pred_up = preds_summary[name]\n    pred_up.index = pd.to_datetime(pred_up.index)\n    \n    print('flip ratio', (pred_up - pred_up.shift()).abs().mean())\n    \n    # indicator = pred_up[pred_up==1].index\n    \n    res = sim_indicator(pred_up, name)\n    result_all[name] = res"

# %%
'''result_all = {}


for fast in ll:
    for slow in ll:
        if slow > fast:
                fast_indicator = ewma(price.shift(), fast)[start:]
                slow_indicator = ewma(price.shift(), slow)[start:]
                indicator_name_list = ['EMA{}'.format(fast), 'EMA{}'.format(slow)]
                res = sim_fast_slow_indicator(fast_indicator, slow_indicator, indicator_name_list)
                result_all['EMA_{}_{}'.format(fast, slow)] = res'''
# Out:
# "result_all = {}\n\n\nfor fast in ll:\n    for slow in ll:\n        if slow > fast:\n                fast_indicator = ewma(price.shift(), fast)[start:]\n                slow_indicator = ewma(price.shift(), slow)[start:]\n                indicator_name_list = ['EMA{}'.format(fast), 'EMA{}'.format(slow)]\n                res = sim_fast_slow_indicator(fast_indicator, slow_indicator, indicator_name_list)\n                result_all['EMA_{}_{}'.format(fast, slow)] = res"

# %%
pred_3ema = pd.read_csv('pred_3ema.csv', index_col=0)
pred_3ema.index = pd.to_datetime(pred_3ema.index)
pred_3ema = pred_3ema[start:end]
pred_3ema
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-81-6237adba3c17> in <module>
# ----> 1 pred_3ema = pd.read_csv('pred_3ema.csv', index_col=0)
#       2 pred_3ema.index = pd.to_datetime(pred_3ema.index)
#       3 pred_3ema = pred_3ema[start:end]
#       4 pred_3ema
#
# ...

# %%
# try rolling

# %%
#met_y = ret_all.groupby(pd.Grouper(freq='A')).apply(lambda x: empy_metric(x)['return/avgdd']).shift()
#met_y

# %%
#met_y.max(1)

# %%
#pred_all

# %%
#for y, score in met_y.T.items():
#    print(y)
#    print(score)

# %%
#vote_se = pd.Series(1, ret_all.index)

lookback_list = ['10A', '5A', '3A', 'A', 'M']
roll_list = ['A', 'A', 'A', 'A', 'M']
top_n_list = [4,6,10,20,30,60,90]
#top_n_name_list = ['vote_c3ema_roll_top{}'.format(n) for n in top_n_list]
#top_n_name_list = []


pred_sub = pd.DataFrame(1, ret_all.index, ['c3ema'])
pred_sub['c3ema'] = pred_3ema


chosen_df = {}
for l in lookback_list:
    for n in top_n_list:
        chosen_df[(l, n)] = pd.DataFrame()

for l,f in zip(lookback_list, roll_list):
    
    met_y = ret_all.groupby(pd.Grouper(freq=f)).apply(lambda x: empy_metric(x)['return/avgdd']).shift()
    #display(met_y)
    
    r_str = l.replace(f,'')
    r_str = r_str if r_str else 1
    
    met_y = met_y.rolling(int(r_str)).sum()
    #display(met_y)
    
    for y, score in met_y.T.items():
        y_str = str(y)[:4] if 'A' in f else str(y)[:7]
        #print(y_str)
        top_idx_all = score.nlargest(max(top_n_list)).index
        
        for n in top_n_list:
            top_n_name = 'vote_c3ema_lookback{}_roll{}_top{}'.format(l, f, n)
            
            
            
            #top_idx = score.nlargest(n).index
            top_idx = top_idx_all[:n]
            
            chosen_df[(f, n)].loc[y_str, top_idx] = 1
            
            
            vote_df_tmp = pd.concat([pred_3ema[y_str]]+[pred_all[x][y_str] for x in top_idx], 1)
            vote_tmp = vote_df_tmp.mean(1).apply(lambda x: 0 if x<0.5 else 1)
            pred_sub.loc[y_str, top_n_name] = vote_tmp

    
for f in roll_list:
    for n in top_n_list:
        chosen_df[(f, n)] = chosen_df[(f, n)].fillna(0)
    
#vote_se
#display(pred_sub)
#display(chosen_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-40b7ff25aa5b> in <module>
#       9
#      10 pred_sub = pd.DataFrame(1, ret_all.index, ['c3ema'])
# ---> 11 pred_sub['c3ema'] = pred_3ema
#      12
#      13
#
# NameError: name 'pred_3ema' is not defined

# %%
for f in roll_list:
    for n in top_n_list:
        print(f, n)
        #display(chosen_df[(f, n)].mean().sort_values())
        
        fig, ax = plt.subplots()
        chosen_df[(f, n)].mean().sort_values().iloc[-5:].plot.barh()
        #ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.show()
# Out:
# A 4
# A 6
# A 10
# A 20
# A 30
# A 60
# A 90
# A 4
# A 6
# A 10
# A 20
# A 30
# A 60
# A 90
# A 4
# A 6
# A 10
# A 20
# A 30
# A 60
# A 90
# A 4
# A 6
# A 10
# A 20
# A 30
# A 60
# A 90
# M 4
# M 6
# M 10
# M 20
# M 30
# M 60
# M 90

# %%
#pred_sub.plot()

# %%
pred_3ema.plot()

# %%
#(pred_sub.vote_c3ema_roll_top4 - pred_sub.vote_c3ema_roll_top6).plot()

# %%
#pred_all = pd.DataFrame(pred_all).reindex(ret_all.index).ffill()
pred_all.shape
# Out:
# (9639, 111)

# %%
ret_all.shape
# Out:
# (9612, 111)

# %%
other_metric_all.shape
# Out:
# (110, 5)

# %%
empy_metric_all.shape
# Out:
# (111, 8)

# %%
pred_sub.shape
# Out:
# (9612, 36)

# %%
ret_sub = pred_sub.multiply(true_ret, 0)
ret_sub.shape
# Out:
# (9612, 36)

# %%
other_metric_sub = other_metric(ret_sub)
other_metric_sub
# Out:
#                                     highlight_ratio  flip_ratio      accu  \
# c3ema                                      0.578236    0.011757  0.522576
# vote_c3ema_lookback10A_rollA_top4          0.475239    0.107065  0.513837
# vote_c3ema_lookback10A_rollA_top6          0.454848    0.107689  0.511340
# vote_c3ema_lookback10A_rollA_top10         0.436226    0.104984  0.512484
# vote_c3ema_lookback10A_rollA_top20         0.432688    0.111227  0.509363
# vote_c3ema_lookback10A_rollA_top30         0.424469    0.097701  0.505306
# vote_c3ema_lookback10A_rollA_top60         0.428631    0.086255  0.506554
# vote_c3ema_lookback10A_rollA_top90         0.428111    0.082510  0.509363
# vote_c3ema_lookback5A_rollA_top4           0.479817    0.119759  0.509675
# vote_c3ema_lookback5A_rollA_top6           0.447774    0.128499  0.509675
# vote_c3ema_lookback5A_rollA_top10          0.442156    0.126210  0.511132
# vote_c3ema_lookback5A_rollA_top20          0.439035    0.130163  0.510508
# ...

# %%
empy_metric_sub = empy_metric(ret_sub)
empy_metric_sub
# Out:
#                                     total_return  annual_return  sharpe_ratio  \
# c3ema                                   8.240547       0.060029      0.532588
# vote_c3ema_lookback10A_rollA_top4       5.502046       0.050306      0.494359
# vote_c3ema_lookback10A_rollA_top6       4.409992       0.045255      0.460750
# vote_c3ema_lookback10A_rollA_top10      4.218060       0.044266      0.468627
# vote_c3ema_lookback10A_rollA_top20      4.353804       0.044969      0.482736
# vote_c3ema_lookback10A_rollA_top30      3.082781       0.037570      0.417250
# vote_c3ema_lookback10A_rollA_top60      3.572918       0.040659      0.437056
# vote_c3ema_lookback10A_rollA_top90      5.032716       0.048245      0.511424
# vote_c3ema_lookback5A_rollA_top4        3.663437       0.041194      0.420130
# vote_c3ema_lookback5A_rollA_top6        2.740487       0.035191      0.378378
# vote_c3ema_lookback5A_rollA_top10       3.754658       0.041723      0.438411
# ...

# %%
pred_all_sub = pd.concat([pred_all, pred_sub], 1)
pred_all_sub.shape
# Out:
# (9641, 147)

# %%
ret_all_sub = pd.concat([ret_all, ret_sub], 1)
ret_all_sub.shape
# Out:
# (9612, 147)

# %%
other_metric_all_sub = pd.concat([other_metric_all, other_metric_sub])
other_metric_all_sub.shape
# Out:
# (146, 5)

# %%
empy_metric_all_sub = pd.concat([empy_metric_all, empy_metric_sub])
empy_metric_all_sub.shape
# Out:
# (147, 8)

# %%
"""name_list = []
se_list = []
name_list.append('buy_and_hold')
se_list.append(empy_metric(true_ret))

for name, r in result_all.items():
    #print(name)
    #print(r['empy_metric'])
    #empy_metric_all[name] = r['empy_metric'].iloc[0]
    name_list.append(name)
    se_list.append(r['empy_metric'].iloc[0])

    
empy_metric_all = pd.concat(se_list, 1, keys=name_list).T
"""
# Out:
# "name_list = []\nse_list = []\nname_list.append('buy_and_hold')\nse_list.append(empy_metric(true_ret))\n\nfor name, r in result_all.items():\n    #print(name)\n    #print(r['empy_metric'])\n    #empy_metric_all[name] = r['empy_metric'].iloc[0]\n    name_list.append(name)\n    se_list.append(r['empy_metric'].iloc[0])\n\n    \nempy_metric_all = pd.concat(se_list, 1, keys=name_list).T\n"

# %%
empy_metric_all_good_return = empy_metric_all_sub.sort_values('annual_return').loc['buy_and_hold':]

# %%
display(empy_metric_all_good_return)
# Out:
#                                                     total_return  \
# buy_and_hold                                            4.930555
# vote_c3ema_lookback10A_rollA_top90                      5.032716
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...      5.075801
# vote_c3ema_lookbackM_rollM_top10                        5.080590
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...      5.111786
# vote_c3ema_lookback10A_rollA_top4                       5.502046
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...      5.525298
# pp10=xgbc(all_index_(EMA_return_all34+dd_vol))          6.524024
# c3ema                                                   8.240547
#
#                                                     annual_return  \
# buy_and_hold                                             0.047776
# vote_c3ema_lookback10A_rollA_top90                       0.048245
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...       0.048441
# ...

# %%
empy_metric_all_good_sharpe = empy_metric_all_sub.sort_values('sharpe_ratio').loc['buy_and_hold':]

# %%
display(empy_metric_all_good_sharpe)
# Out:
#                                                     total_return  \
# buy_and_hold                                            4.930555
# vote_c3ema_lookback5A_rollA_top6                        2.740487
# vote_c3ema_lookback5A_rollA_top60                       2.772270
# vote_c3ema_lookback3A_rollA_top30                       2.639227
# vote_c3ema_lookback3A_rollA_top10                       2.832361
# vote_c3ema_lookbackM_rollM_top30                        2.816515
# vote_c3ema_lookbackA_rollA_top10                        2.732798
# pp5=xgbc(all_index_(EMA_return_all34+cross_EMA_...      2.807968
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...      3.242497
# pp5=xgbc(all_index_(EMA_return_all34+dd_vol+exc...      2.759455
# pp21=xgbc(EMA_return_all34)                             2.749644
# pp21=xgbc(all_xau_(EMA_return_all34))                   2.909480
# vote_c3ema_lookbackA_rollA_top60                        2.800658
# ...

# %%
empy_metric_tmp = empy_metric_all_sub.sort_values('max_drawdown').loc['buy_and_hold':]
display(empy_metric_tmp)
# Out:
#                                                     total_return  \
# buy_and_hold                                            4.930555
# pp5=xgbc(all_index_(pca(EMA_return_all34+cross_...      0.705055
# pp21=xgbc(all_index_(pca(EMA_return_all34+dd_vo...      1.697248
# pp5=xgbc(all_index_(EMA_return_all34+dd_vol+exc...      1.584371
# vote_c3ema_lookbackM_rollM_top90                        2.217111
# ...                                                          ...
# vote_c3ema_lookback10A_rollA_top20                      4.353804
# vote_c3ema_lookback10A_rollA_top60                      3.572918
# pp10=xgbc(all_index_(EMA_return_all34+dd_vol))          6.524024
# pp5=xgbc(price_position)                                1.440244
# vote_c3ema_lookback10A_rollA_top10                      4.218060
#
#                                                     annual_return  \
# buy_and_hold                                             0.047776
# ...

# %%
empy_metric_tmp = empy_metric_all_sub.sort_values('avg_drawdown').loc['buy_and_hold':]
display(empy_metric_tmp)
# Out:
#                                                     total_return  \
# buy_and_hold                                            4.930555
# pp5=xgbc(all_index_(pca(EMA_return_all34+cross_...      0.705055
# pp21=xgbc(all_index_(pca(EMA_return_all34+up_dd...      1.194975
# pp5=xgbc(all_index_(EMA_return_all34+up_dd_volm...      0.501240
# pp10=xgbc(EMA_return_all34+dd_vol+TA+excel+pric...      0.202607
# ...                                                          ...
# vote_c3ema_lookback10A_rollA_top90                      5.032716
# pp5=xgbc(price_position)                                1.440244
# pp10=xgbc(all_index_(pca(EMA_return_all34+up_dd...      2.412074
# vote_c3ema_lookback10A_rollA_top10                      4.218060
# pp10=xgbc(all_index_(EMA_return_all34+dd_vol))          6.524024
#
#                                                     annual_return  \
# buy_and_hold                                             0.047776
# ...

# %%
empy_metric_tmp = empy_metric_all_sub.sort_values('return/maxdd').loc['buy_and_hold':]
display(empy_metric_tmp)
# Out:
#                                                     total_return  \
# buy_and_hold                                            4.930555
# pp10=xgbc(all_index_(pca(EMA_return_all34+dd_vo...      2.654311
# vote_c3ema_lookbackM_rollM_top4                         2.479130
# vote_c3ema_lookback3A_rollA_top4                        1.978415
# pp21=xgbc(all_index_(EMA_return_all34+cross_EMA...      2.416658
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...      5.111786
# vote_c3ema_lookbackA_rollA_top90                        3.021400
# vote_c3ema_lookback3A_rollA_top30                       2.639227
# pp5=xgbc(price_position)                                1.440244
# vote_c3ema_lookback5A_rollA_top10                       3.754658
# pp10=xgbc(all_index_(EMA_return_all34+dd_vol+ex...      4.431470
# pp21=xgbc(all_index_(EMA_return_all34+cross_EMA...      4.616753
# vote_c3ema_lookbackA_rollA_top60                        2.800658
# ...

# %%
### return/avgdd top10 new feature only 

empy_metric_tmp = empy_metric_all_sub.sort_values('return/avgdd')#.loc['buy_and_hold':]


list_tmp = [i for i in empy_metric_tmp.index if ('buy_and_hold' in i) 
            or ('(dd_vol' in i)
            or ('(price_position' in i)
            or ('(TA' in i)
            or ('(all_xau' in i)
           ]
empy_metric_tmp = empy_metric_tmp.loc[list_tmp]

column_selected = ['annual_return','sharpe_ratio','avg_drawdown','return/avgdd',]
#display(empy_metric_tmp[column_selected])


strategy_list_sel = list(empy_metric_tmp.index)

#strategy_list_sel = strategy_list_sel[-10:]
if 'buy_and_hold' in strategy_list_sel:
    strategy_list_sel = [x for x in strategy_list_sel if x !='buy_and_hold']
strategy_list_sel = ['buy_and_hold']+strategy_list_sel


if 'buy_and_hold' not in strategy_list_sel:
    strategy_list_sel = ['buy_and_hold']+strategy_list_sel
else:
    strategy_list_sel = [x for x in strategy_list_sel if x !='buy_and_hold']
    strategy_list_sel = ['buy_and_hold']+strategy_list_sel

display(other_metric_all_sub.loc[strategy_list_sel[1:]].iloc[:,:5])
display(empy_metric_all_sub.loc[strategy_list_sel][column_selected])

#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].accu.plot(ax=ax)
#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].prec.plot(ax=ax)
#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].mse.plot(ax=ax)
    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
# Out:
#                                        highlight_ratio  flip_ratio      accu  \
# pp10=xgbc(price_position)                     0.297233    0.170014  0.483978
# pp5=xgbc(TA)                                  0.459010    0.118094  0.492405
# pp10=xgbc(TA+price_position)                  0.463379    0.110915  0.494278
# pp5=xgbc(TA+price_position)                   0.441323    0.116013  0.494070
# pp5=xgbc(all_index_(dd_vol))                  0.489700    0.076475  0.491677
# pp21=xgbc(price_position)                     0.311798    0.172927  0.493550
# pp10=xgbc(all_index_(dd_vol+TA))              0.487308    0.150453  0.498856
# pp5=xgbc(all_index_(dd_vol+TA))               0.466396    0.170950  0.500624
# pp21=xgbc(TA)                                 0.468165    0.100510  0.498648
# pp21=xgbc(TA+price_position)                  0.467437    0.097180  0.495214
# pp21=xgbc(all_index_(dd_vol+TA))              0.478464    0.123608  0.505202
# ...

# %%
### return/avgdd top10 vote only 

empy_metric_tmp = empy_metric_all_sub.sort_values('return/avgdd')#.loc['buy_and_hold':]


list_tmp = [i for i in empy_metric_tmp.index if ('buy_and_hold' in i) 
            or ('vote_c3ema_' in i)
            
           ]
empy_metric_tmp = empy_metric_tmp.loc[list_tmp]

column_selected = ['annual_return','sharpe_ratio','avg_drawdown','return/avgdd',]
#display(empy_metric_tmp[column_selected])


strategy_list_sel = list(empy_metric_tmp.index)

if 'buy_and_hold' in strategy_list_sel:
    strategy_list_sel = [x for x in strategy_list_sel if x !='buy_and_hold']
strategy_list_sel = strategy_list_sel[-10:]
strategy_list_sel = ['buy_and_hold']+strategy_list_sel

display(other_metric_all_sub.loc[strategy_list_sel[1:]].iloc[:,:5])
display(empy_metric_all_sub.loc[strategy_list_sel][column_selected])

#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].accu.plot(ax=ax)
#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].prec.plot(ax=ax)
#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].mse.plot(ax=ax)
    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
# Out:
#                                     highlight_ratio  flip_ratio      accu  \
# vote_c3ema_lookbackA_rollA_top20           0.441635    0.123921  0.507074
# vote_c3ema_lookback10A_rollA_top6          0.454848    0.107689  0.511340
# vote_c3ema_lookbackA_rollA_top30           0.439971    0.120591  0.507491
# vote_c3ema_lookbackM_rollM_top10           0.435601    0.153678  0.511028
# vote_c3ema_lookback10A_rollA_top30         0.424469    0.097701  0.505306
# vote_c3ema_lookback10A_rollA_top60         0.428631    0.086255  0.506554
# vote_c3ema_lookback10A_rollA_top4          0.475239    0.107065  0.513837
# vote_c3ema_lookback10A_rollA_top20         0.432688    0.111227  0.509363
# vote_c3ema_lookback10A_rollA_top10         0.436226    0.104984  0.512484
# vote_c3ema_lookback10A_rollA_top90         0.428111    0.082510  0.509363
#
#                                         prec       mse
# vote_c3ema_lookbackA_rollA_top20    0.527208  1.236134
# ...

# %%
"""strategy_list_sel = ['buy_and_hold','vote_c3ema_rollA_top30']

fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
"""
# Out:
# 'strategy_list_sel = [\'buy_and_hold\',\'vote_c3ema_rollA_top30\']\n\nfig, ax = plt.subplots(figsize=(12,6))\n\ncm = plt.get_cmap(\'gist_rainbow\')\nNUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]\nax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])\n\n\n(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)\nax.legend(loc=\'center left\', bbox_to_anchor=(1, 0.5))\nax.set_yscale("log")\n'

# %%
### return/avgdd top10 

empy_metric_tmp = empy_metric_all_sub.sort_values('return/avgdd').loc['buy_and_hold':]

column_selected = ['annual_return','sharpe_ratio','avg_drawdown','return/avgdd',]
#display(empy_metric_tmp[column_selected])


strategy_list_sel = list(empy_metric_tmp.index)

strategy_list_sel = strategy_list_sel[-10:]
if 'buy_and_hold' not in strategy_list_sel:
    strategy_list_sel = ['buy_and_hold']+strategy_list_sel


display(other_metric_all_sub.loc[strategy_list_sel[1:]].iloc[:,:5])
display(empy_metric_all_sub.loc[strategy_list_sel][column_selected])

#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].accu.plot(ax=ax)
#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].prec.plot(ax=ax)
#fig, ax = plt.subplots(figsize=(12,6))
#other_metric_all.loc[strategy_list_sel[1:]].mse.plot(ax=ax)
    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
# Out:
#                                                     highlight_ratio  \
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...         0.536725
# vote_c3ema_lookbackM_rollM_top10                           0.435601
# vote_c3ema_lookback10A_rollA_top30                         0.424469
# vote_c3ema_lookback10A_rollA_top60                         0.428631
# vote_c3ema_lookback10A_rollA_top4                          0.475239
# c3ema                                                      0.578236
# vote_c3ema_lookback10A_rollA_top20                         0.432688
# vote_c3ema_lookback10A_rollA_top10                         0.436226
# vote_c3ema_lookback10A_rollA_top90                         0.428111
# pp10=xgbc(all_index_(EMA_return_all34+dd_vol))             0.493446
#
#                                                     flip_ratio      accu  \
# pp21=xgbc(all_index_(pca(EMA_return_all34+cross...    0.069400  0.499584
# ...

# %%
"""list_tmp = [
    'pp10=xgbc(all_index_(EMA_return_all34+dd_vol))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol)))',
    'pp21=xgbc(all_index_(EMA_return_all34+dd_vol+excel+excel_cross))',
    'pp10=xgbc(all_index_(pca(EMA_return_all34+up_dd_volm+sd_rsi)))',
    'pp21=xgbc(all_index_(EMA_return_all34+cross_EMA_price_fib34+dd_vol))',
    'pp10=xgbc(all_index_(EMA_return_all34+up_dd_volm))',
    
    
]
pred_top_tmp = pd.concat([pred_all[n] for n in list_tmp], 1, keys=list_tmp).ffill()[start:].fillna(1)
pred_top_tmp.to_csv('pred_top_tmp3.csv')"""

# %%
"""
list_tmp = [
    'vote_c3ema_rollA_top30',
    
    
]
pred_top_tmp = pd.concat([pred_all_sub[n] for n in list_tmp], 1, keys=list_tmp).ffill()[start:].fillna(1)

pred_top_tmp.columns = ['y_pred']

display(pred_top_tmp)

pred_top_tmp.to_csv('pred_vote_c3ema_rollA_top30.csv')"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vote_c3ema_rollA_top30'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-209-481087a2de21> in <module>()
#       5
# ...

# %%
"""#strategy_list_sel = ['buy_and_hold','pred_vote_crossema_4xgb','pred_vote_crossema_6xgb']
#strategy_list_sel = ['buy_and_hold','vote_c3ema_roll_top4','vote_c3ema_roll_top6']
strategy_list_sel = ['buy_and_hold','c3ema','vote_c3ema_rollM_top6']
#strategy_list_sel = ['buy_and_hold'] + list(pred_sub.columns)

display(empy_metric_all_sub.loc[strategy_list_sel])



fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")"""

# %%
#set(empy_metric_all_good_sharpe.index) - set(empy_metric_all_good_return.index)

# %%
#set(empy_metric_all_good_return.index) - set(empy_metric_all_good_sharpe.index)

# %%
#empy_metric_all_good_sharpe.to_csv('empy_metric_all_good_sharpe_20220406.csv')

# %%
"""
fig, ax = plt.subplots(figsize=(16,9))


cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all.shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])



(1+ret_all).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
plt.show()
"""

# %%
"""
fig, ax = plt.subplots(figsize=(16,9))

'''
cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all[['buy_and_hold', 'ema_all_1_34_return___cross_ema_all_1_34_price___10D___sort_feature_prob_cont_2']].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
'''


(1+ret_all[['buy_and_hold', 'ema_all_1_34_return___cross_ema_all_1_34_price___10D___sort_feature_prob_cont_2']]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
plt.show()"""

# %%
"""ret_tmp = ret_all['buy_and_hold']
empy.annual_return(ret_tmp)"""

# %%
"""ret_tmp = ret_all['ema_all_1_34_return___cross_ema_all_1_34_price___5D___sort_feature_prob_cont_5']
empy.annual_return(ret_tmp)"""

# %%
"""ret_tmp = ret_all['ema_all_1_34_return___cross_ema_all_1_34_price___10D___sort_feature_prob_cont_2']
ret_tmp[ret_tmp==0]"""

# %%
"""ret_tmp[ret_tmp == np.nan]"""

# %%
### top20
strategy_list_sel = list(empy_metric_all_good_sharpe.index)

strategy_list_sel = strategy_list_sel[-20:]
if 'buy_and_hold' not in strategy_list_sel:
    strategy_list_sel = ['buy_and_hold']+strategy_list_sel


display(other_metric_all_sub.loc[strategy_list_sel[1:]])
display(empy_metric_all_sub.loc[strategy_list_sel])

fig, ax = plt.subplots(figsize=(12,6))
other_metric_all_sub.loc[strategy_list_sel[1:]].accu.plot(ax=ax)
fig, ax = plt.subplots(figsize=(12,6))
other_metric_all_sub.loc[strategy_list_sel[1:]].prec.plot(ax=ax)
fig, ax = plt.subplots(figsize=(12,6))
other_metric_all_sub.loc[strategy_list_sel[1:]].mse.plot(ax=ax)
    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")

# %%
"""list_tmp = [
    'pp21=xgbc(all_index_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol)))_cont_21_rb_lookback',
    'pp10=xgbc(all_index_(EMA_return_all_1_34+dd_vol))',
    'pp5=xgbc(all_index_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol)))_cont_21_rb_lookback',
    'pp21=xgbc(all_index_(pca(EMA_return_all_1_34+cross_EMA_price_fib_1_34+dd_vol)))_freq_W'
]
pred_top_tmp = pd.concat([pred_all[n] for n in list_tmp], 1, keys=list_tmp).ffill()[start:].fillna(1)
pred_top_tmp.to_csv('pred_top_tmp.csv')"""

# %%
"""strategy_list_sel = ['buy_and_hold',
                     'pred___XAU_USDpp21=EMA_return_all_1_34+cross_EMA_price_all_1_34+dd_vol_freq_M',
                     'pred___XAU_USDpp21=EMA_return_all_1_34+cross_EMA_price_all_1_34+dd_vol_cont_9_rb_lookback']

fig, ax = plt.subplots(figsize=(12,6))
'''
cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
'''

(1+ret_all[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")"""

# %%
"""# excelonly

strategy_list_sel = empy_metric_all.index

strategy_list_sel = [x for x in strategy_list_sel if x=='buy_and_hold' or (('freq' not in x) and ('cont' not in x) and ('(excel' in x))]
strategy_list_sel.sort()


empy_metric_tmp = empy_metric_all.loc[strategy_list_sel].sort_values('sharpe_ratio').iloc[-25:]
empy_metric_tmp2 = pd.concat([empy_metric_all.loc[['buy_and_hold']], empy_metric_tmp])


display(other_metric_all.loc[empy_metric_tmp.drop('buy_and_hold').index])
display(empy_metric_tmp2)


    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
"""

# %%
### nofreqnocont

strategy_list_sel = empy_metric_all_sub.index

strategy_list_sel = [x for x in strategy_list_sel if (('freq' not in x) and ('cont' not in x))]
strategy_list_sel.sort()


empy_metric_tmp = empy_metric_all_sub.loc[strategy_list_sel].sort_values('sharpe_ratio').iloc[-25:]
#empy_metric_tmp2 = pd.concat([empy_metric_all_sub.loc[['buy_and_hold']], empy_metric_tmp])


display(other_metric_all_sub.loc[empy_metric_tmp.index])
display(empy_metric_tmp)


    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")

# %%
list_tmp = [
    'pp10=xgbc(all_index_(EMA_return_all34+dd_vol))',
    'pp21=xgbc(all_index_(EMA_return_all34+dd_vol+excel+excel_cross))',
    'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol)))',
    #'pp21=xgbc(all_index_(pca(EMA_return_all34+cross_EMA_price_fib34+dd_vol+excel+excel_cross)))',
    'pp10=xgbc(all_index_(EMA_return_all34+dd_vol+excel))',
    
]
pred_top_tmp = pd.concat([pred_all_sub[n] for n in list_tmp], 1, keys=list_tmp).ffill()[start:].fillna(1)
pred_top_tmp.to_csv('pred_top_tmp2.csv')

# %%
""" 
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[['buy_and_hold','pred_vote_crossema_4xgb']].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[['buy_and_hold','pred_vote_crossema_4xgb']]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
"""

# %%
"""# freqtop20

strategy_list_sel = empy_metric_all_good_sharpe.index

strategy_list_sel = [x for x in strategy_list_sel if (('freq' in x))]

strategy_list_sel = strategy_list_sel[-20:]
if 'buy_and_hold' not in strategy_list_sel:
    strategy_list_sel = ['buy_and_hold']+strategy_list_sel


display(other_metric_all_sub.loc[strategy_list_sel[1:]])
display(empy_metric_all_sub.loc[strategy_list_sel])

fig, ax = plt.subplots(figsize=(12,6))
other_metric_all_sub.loc[strategy_list_sel[1:]].accu.plot(ax=ax)
fig, ax = plt.subplots(figsize=(12,6))
other_metric_all_sub.loc[strategy_list_sel[1:]].prec.plot(ax=ax)
fig, ax = plt.subplots(figsize=(12,6))
other_metric_all_sub.loc[strategy_list_sel[1:]].mse.plot(ax=ax)
    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all_sub[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all_sub[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
"""

# %%
"""# conttop20

strategy_list_sel = empy_metric_all_good_sharpe.index

strategy_list_sel = [x for x in strategy_list_sel if (('cont' in x))]

strategy_list_sel = strategy_list_sel[-20:]
if 'buy_and_hold' not in strategy_list_sel:
    strategy_list_sel = ['buy_and_hold']+strategy_list_sel


display(other_metric_all.loc[strategy_list_sel[1:]])
display(empy_metric_all.loc[strategy_list_sel])
display(empy_metric_all.loc[strategy_list_sel].iloc[-1])




fig, ax = plt.subplots(figsize=(12,6))
other_metric_all.loc[strategy_list_sel[1:]].accu.plot(ax=ax)
fig, ax = plt.subplots(figsize=(12,6))
other_metric_all.loc[strategy_list_sel[1:]].prec.plot(ax=ax)
fig, ax = plt.subplots(figsize=(12,6))
other_metric_all.loc[strategy_list_sel[1:]].mse.plot(ax=ax)
    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all[strategy_list_sel].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all[strategy_list_sel]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")
"""

# %%
other_metric_all

# %%
strategy_list_vote5tss_all = [i for i in empy_metric_all.index if i=='buy_and_hold' or (
    i.startswith('ema_all_1_34_return___cross_ema_all_1_34_price___5D___') and 
    ('time_series_split' in i or '20220315' in i or 'sort_feature' in i) and
    'set1' in i 
    
)]
     

display(empy_metric_all.loc[strategy_list_vote5tss_all])
display(empy_metric_all.loc[strategy_list_vote5tss_all].mean())


display(other_metric_all.loc[other_metric_all.index.isin(strategy_list_vote5tss_all)])

    
fig, ax = plt.subplots(figsize=(12,6))

cm = plt.get_cmap('gist_rainbow')
NUM_COLORS = ret_all[strategy_list_vote5tss_all].shape[1]
ax.set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])


(1+ret_all[strategy_list_vote5tss_all]).cumprod().plot(ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_yscale("log")

# %%
name_list = []
se_list = []

for name, r in result_all.items():
    #print(name)
    #print(r['empy_metric'])
    #empy_metric_all[name] = r['empy_metric'].iloc[0]
    name_list.append(name)
    se_list.append(r['other_metric'].iloc[0])

    
other_metric_all = pd.concat(se_list, 1, keys=name_list).T
display(other_metric_all.sort_values('accu'))

# %%
scatter_df = pd.concat([empy_metric_all, other_metric_all], 1)

# %%
for yy in ['prec','mse']:
    fig, ax = plt.subplots()
    sns.regplot(data=scatter_df, x="accu", y=yy, ax=ax)

# %%
for yy in ['annual_return','sharpe_ratio']:
    for xx in ['accu','prec','mse']:
    
        fig, ax = plt.subplots()
        sns.regplot(data=scatter_df, x=xx, y=yy, ax=ax)

# %%
"""for yy in ['annual_return','sharpe_ratio']:
    for xx in ['accu5','prec5','mse5']:
        
        fig, ax = plt.subplots()
        sns.regplot(data=scatter_df, x=xx, y=yy, ax=ax)
"""

# %%
"""for yy in ['annual_return','sharpe_ratio']:
    for xx in ['accu10','prec10','mse10']:
    
        fig, ax = plt.subplots()
        sns.regplot(data=scatter_df, x=xx, y=yy, ax=ax)
"""

# %%
"""for yy in ['annual_return','sharpe_ratio']:
    for xx in ['accu21','prec21','mse21']:
    
        fig, ax = plt.subplots()
        sns.regplot(data=scatter_df, x=xx, y=yy, ax=ax)
"""

# %%
annual_return_all = pd.concat([v['empy_metric'].annual_return for v in result_all.values()]).sort_values()

annual_return_all.plot()
annual_return_all.tail(20)

# %%
sharpe_ratio_all = pd.concat([v['empy_metric'].sharpe_ratio for v in result_all.values()]).sort_values()

sharpe_ratio_all.plot()
sharpe_ratio_all.tail(20)

# %%
(ret/ret.std()).plot.density()

# %%
(ret/ret.std()).sort_values().head(10)

# %%
(ret/ret.std()).sort_values().tail(10)

# %%
true_up_pct_scaled = ret/ret.std() + 0.5

# %%
pred_up_all_correct = (ret>=0)*1
mse_all_correct = mean_squared_error(true_up_pct_scaled, pred_up_all_correct)
mse_all_correct

# %%
pred_up_all_wrong = (ret<0)*1
mse_all_wrong = mean_squared_error(true_up_pct_scaled, pred_up_all_wrong)
mse_all_wrong

# %%
pred_up_all_half = ret*0
mse_all_half = mean_squared_error(true_up_pct_scaled, pred_up_all_half)
mse_all_half

# %%
pred_up_all_half = ret*0+0.5
mse_all_half = mean_squared_error(true_up_pct_scaled, pred_up_all_half)
mse_all_half

# %%
pred_up_all_half = ret*0+1
mse_all_half = mean_squared_error(true_up_pct_scaled, pred_up_all_half)
mse_all_half

# %%
temp_df = pd.DataFrame(prob_all)[start:end]
#temp_df = temp_df[[i for i in strategy_list_vote5tss if i in temp_df.columns]]
#print_clustermap(temp_df)
#temp_df.plot.density()

# %%
temp_df.applymap(lambda x: 0 if x<0.5 else 1).plot()

# %%
temp_df.applymap(lambda x: 0 if x<0.5 else 1).groupby(pd.Grouper(freq='M')).first().plot()

# %%
temp_df.plot()

# %%
temp_df.min()

# %%
temp_df.max()

# %%
'''temp_df = pd.DataFrame(pred_all)[start:end]
temp_df = temp_df[[i for i in strategy_list_5fc if i in temp_df.columns]]
print_clustermap(temp_df)'''

# %%
'''temp_df = pd.DataFrame(pred_all)[start:end]
temp_df = temp_df[[i for i in strategy_list_vote5sf if i in temp_df.columns]]
temp_df'''

# %%
temp_df.plot()

# %%
temp_df = pd.DataFrame(pred_all)[start:end]
pp21_list = [i for i in temp_df.columns if '___21D___' in i]
temp_df = temp_df.loc[:,temp_df.columns.isin(pp21_list)]
temp_df

# %%
temp_df.columns

# %%
#temp_df.to_csv('pred_xauusd_pp21.csv')
